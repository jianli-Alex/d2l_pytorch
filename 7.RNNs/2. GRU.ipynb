# %%
# %config ZMQInteractiveShell.ast_node_interactivity = "all"
# %pprint
# Out:
# Pretty printing has been turned OFF

# %%
import os
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"

# %%
import sys
import torch
import torch.nn as nn
sys.path.append("../d2l_func/")
from data_prepare import load_data_jay_song, data_iter_random, data_iter_consecutive, to_onehot
from model_train import train_rnn, train_rnn_pytorch
from set_seed import set_seed

# %% [markdown]
# ## GRU

# %% [markdown]
# 当时间步过小或者过大时，RNN往往会出现梯度爆炸或者梯度消失的问题
# - 梯度爆炸：可以通过梯度剪裁来解决
# - 梯度消失：可以通过GRU/LSTM等来进行缓解

# %% [markdown]
# GRU包含重置门和更新门
# - 重置门用于捕捉短期依赖关系
# - 更新门用于捕捉长期依赖关系
# - 重置门：$r_t = \delta(x_tw_{xr} + h_{t-1}w_{hr} + b_r)$
# - 更新门：$z_t = \delta(x_tw_{xz} + h_{t-1}w_{hz} + b_z)$
# - 候选隐藏层状态：$\widetilde h_t = tanh(x_tw_{xh} + r_t*(h_{t-1}w_hh) + b_h)$
# - 当前时间步的隐藏层：$h_t = z*h_{t-1} + (1-z)\widetilde h_t$
# - 输出层：$y_t = h_tw_{hy} + b_y$

# %% [markdown]
# ### 自定义实现

# %% [markdown]
# #### 定义网络参数

# %%
def get_params(input_num, hidden_num, output_num, device):
    def _ones(shape):
        weight = nn.Parameter(torch.normal(0, 0.01, size=shape, device=device), requires_grad=True)
        return weight
    
    def _zeros(shape):
        bias = nn.Parameter(torch.zeros(shape, device=device), requires_grad=True)
        return bias
    
    def _three():
        return (
            _ones((input_num, hidden_num)),
            _ones((hidden_num, hidden_num)),
            _zeros(hidden_num),
        )
    
    w_xr, w_hr, b_r = _three()
    w_xz, w_hz, b_z = _three()
    w_xh, w_hh, b_h = _three()
    w_hy = _ones((hidden_num, output_num))
    b_y = _zeros((output_num))
    return nn.ParameterList([w_xr, w_hr, b_r, w_xz, w_hz, b_z, w_xh, w_hh, b_h, w_hy, b_y])

# %% [markdown]
# #### 定义gru层结构

# %%
from functools import reduce

def init_hidden_state(batch_size, hidden_num, device):
    return torch.zeros(batch_size, hidden_num, device=device)


def gru(inputs, h_state, params):
    w_xr, w_hr, b_r, w_xz, w_hz, b_z, w_xh, w_hh, b_h, w_hy, b_y = params
    outputs = []
    
    # inputs.shape is (num_step, batch_size, vocab_size)
    for x in inputs:
        rt = torch.sigmoid(torch.mm(x, w_xr) + torch.mm(h_state, w_hr) + b_r)
        zt = torch.sigmoid(torch.mm(x, w_xz) + torch.mm(h_state, w_hz) + b_z)
        h_candidate = torch.tanh(torch.mm(x, w_xh) + rt*torch.mm(h_state, w_hh) + b_h)
        h_state = zt*h_state + (1-zt)*h_candidate
        y = torch.mm(h_state, w_hy) + b_y
        outputs.append(y.unsqueeze(0))
        
    return reduce(lambda x, y: torch.cat((x, y)), outputs), h_state

# %%
# 验证
vocab_size, hidden_num = 15, 10
x = torch.arange(10).view(2, 5)
inputs = to_onehot(x, vocab_size, "cuda")
h_state = init_hidden_state(x.shape[0], hidden_num, "cuda")
params = get_params(vocab_size, hidden_num, vocab_size, "cuda")
outputs, h_state = gru(inputs, h_state, params)
outputs.shape, h_state.shape
# Out:
# (torch.Size([5, 2, 15]), torch.Size([2, 10]))

# %% [markdown]
# #### 字符级别预测

# %%
def predict_rnn(prefix, pred_num, model, init_hidden_state, hidden_num, 
                params, char_to_idx, vocab_set, vocab_size, device):
    outputs = [char_to_idx[prefix[0]]]
    h_state = init_hidden_state(1, hidden_num, device)
    
    for i in range(len(prefix) + pred_num - 1):
        # inputs.shape is (1, 1, vocab_size)
        inputs = to_onehot(torch.tensor(outputs[-1]).view(-1, 1), vocab_size, device)
        # y.shape is (1, 1, vocab_size), h_state.shape is (1, hidden_num)
        y, h_state = model(inputs, h_state, params)
        
        if i + 1 < len(prefix):
            outputs.append(char_to_idx[prefix[i+1]])
        else:
            outputs.append(y.argmax(dim=2).item())
            
    return "".join(vocab_set[i] for i in outputs)

# %%
# 验证
# load data
corpus_index, char_to_idx, vocab_set, vocab_size = load_data_jay_song()
# params
hidden_num, device = 256, "cuda"
params = get_params(vocab_size, hidden_num, vocab_size, device)
predict_rnn("分开", 10, gru, init_hidden_state, hidden_num, params, char_to_idx, vocab_set, vocab_size, device)
# Out:
# '分开宇墓2江伽逝星蹈哈哈'

# %% [markdown]
# #### 梯度剪裁

# %%
def grad_clipping(params, clipping_theta, device):
    # l2 norm
    norm = torch.zeros(1, device=device)
    # cumsum all grad data
    for param in params:
        norm += (param.grad.data ** 2).sum()
        
    norm = norm.sqrt()
    
    # grad explode
    if norm > clipping_theta:
        for param in params:
            param.grad.data *= (clipping_theta / norm)

# %% [markdown]
# #### 训练

# %%
# training
import numpy as np
from sqdm import sqdm
from optim import sgd

def train_rnn(epoch_num, batch_num, model, loss, get_params, init_hidden_state, hidden_num, batch_size,
              lr, data_iter, prefixs, pred_num, corpus_index, char_to_idx, vocab_set, vocab_size, 
              num_step, predict_rnn, clipping_theta=1e-2, random_sample=True, device="cuda"):
    
    # init(use in calculate perplexity)
    l_sum, n_class = 0., 0.
    # training bar
    process_bar = sqdm()
    # init params
    params = get_params(vocab_size, hidden_num, vocab_size, device)
    
    for epoch in range(epoch_num):
        print(f"Epoch [{epoch+1}/{epoch_num}]")
        # sample in consecutive
        if not random_sample:
            h_state = init_hidden_state(batch_size, hidden_num, device)
        for x, y in data_iter(corpus_index, batch_size, num_step, device):
            # 原始x的shape为(batch_size, num_step)，onehot后的shape为(num_step, batch_size, vocab_size)
            x = to_onehot(x, vocab_size, device)
            if random_sample:
                h_state = init_hidden_state(x.shape[1], hidden_num, device)
            else:
                # 脱离计算图，使得上一时刻的隐藏状态变成叶子节点，防止在销毁计算图后（隐藏节点还存在），因反向传播到更早的
                # 隐藏层时刻（不在当前计算图内）而出错
                h_state.detach_()
                
            # model
            # outputs.shape is (num_step, batch_size, vocab_size), h_state.shape is (batch_size, hidden_num)
            outputs, h_state = model(x, h_state, params)
            # change output.shape --> (num_step, batch_size, vocab_size), 主要是为了方便计算loss
            outputs = outputs.view(-1, outputs.shape[-1])
            # 原始y的shape为(batch_size, num_step), ---> (num_step, batch_size) ---> 1维向量
            # 转置后变成内存不连续，使用contiguous变成连续的向量
            y = y.transpose(0, 1).contiguous().view(-1)
            
            # 计算loss, 标签需要是int
            l = loss(outputs, y.long())
            # grad clear
            if params[0].grad is not None:
                for param in params:
                    param.grad.data.zero_()
            # grad backward
            l.backward()
            # grad clipping
            grad_clipping(params, clipping_theta, device)
            # update grad
            sgd(params, lr)
            
            # calculate l_sum
            l_sum += l.item() * y.shape[0]
            n_class += y.shape[0]
            
            # calculate perplexity
            try:
                perplexity = np.exp(l_sum / n_class)
            except OverflowError:
                perplexity = float("inf")
                
            # training bar
            process_bar.show_process(batch_num, 1, perplexity)
        print("\n")
        # predict
        for prefix in prefixs:
            print(f"prefix-{prefix}: ", predict_rnn(prefix, pred_num, model, init_hidden_state, hidden_num, 
                                                    params, char_to_idx, vocab_set, vocab_size, device))
        print("\n")

# %%
# load data
corpus_index, char_to_idx, vocab_set, vocab_size = load_data_jay_song()

super_params = {
        "epoch_num": 250,
        "model": gru,
        "loss": nn.CrossEntropyLoss(),
        "init_hidden_state": init_hidden_state,
        "hidden_num": 256,
        "get_params": get_params,
        "batch_size": 64,
        "num_step": 32,
        "corpus_index": corpus_index,
        "data_iter": data_iter_random,
        "lr": 100,
        "char_to_idx": char_to_idx,
        "vocab_set": vocab_set,
        "vocab_size": vocab_size,
        "predict_rnn": predict_rnn,
        "pred_num": 50,
        "prefixs": ["分开", "不分开"],
        #     "random_sample": False
    }

super_params["batch_num"] = len(list(data_iter_random(corpus_index, super_params["batch_size"],
                                                      super_params["num_step"], "cpu")))

train_rnn(**super_params)
# Out:
# Epoch [1/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 856.6398, train_score: -, test_loss: -, test_score: --
#
# prefix-分开:  分开
# prefix-不分开:  不分开
#
#
# Epoch [2/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 683.0150, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的
# prefix-不分开:  不分开的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的
#
#
# Epoch [3/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 614.0556, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开
# prefix-不分开:  不分开
#
#
# Epoch [4/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 573.0361, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我
# prefix-不分开:  不分开我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我我
#
#
# Epoch [5/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 546.0447, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开
# prefix-不分开:  不分开
#
#
# Epoch [6/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 525.6956, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开的的的 我我的的的 我我的的的 我我的的的 我我的的的 我我的的的 我我的的的 我我的的的 我我的的
# prefix-不分开:  不分开的的的 我我的的的 我我的的的 我我的的的 我我的的的 我我的的的 我我的的的 我我的的的 我我的的
#
#
# Epoch [7/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 509.8341, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开
# prefix-不分开:  不分开
#
#
# Epoch [8/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 496.6718, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开的 我我的 我我的 我我的 我我的 我我的 我我的 我我的 我我的 我我的 我我的 我我的 我我的
# prefix-不分开:  不分开的 我我的 我我的 我我的 我我的 我我的 我我的 我我的 我我的 我我的 我我的 我我的 我我的
#
#
# Epoch [9/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 485.7130, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开  我  我  我  我  我  我  我  我  我  我  我  我  我  我  我  我
# prefix-不分开:  不分开  我  我  我  我  我  我  我  我  我  我  我  我  我  我  我  我
#
#
# Epoch [10/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 475.8371, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开的 我不的 我不的 我不的 我不的 我不的 我不的 我不的 我不的 我不的 我不的 我不的 我不的
# prefix-不分开:  不分开的 我不的 我不的 我不的 我不的 我不的 我不的 我不的 我不的 我不的 我不的 我不的 我不的
#
#
# Epoch [11/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 467.0688, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我 我  我  我  我  我  我  我  我  我  我  我  我  我  我  我  我
# prefix-不分开:  不分开 我 我  我  我  我  我  我  我  我  我  我  我  我  我  我  我  我
#
#
# Epoch [12/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 458.8857, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我不的 我不的 我不的 我不的 我不的 我不的 我不的 我不的 我不的 我不的 我不的 我不的 我
# prefix-不分开:  不分开 我不的 我不的 我不的 我不的 我不的 我不的 我不的 我不的 我不的 我不的 我不的 我不的 我
#
#
# Epoch [13/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 451.2423, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我
# prefix-不分开:  不分开 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我
#
#
# Epoch [14/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 443.7412, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我不不的 我不的 我不的 我不的 我不的 我不的 我不的 我不的 我不的 我不的 我不的 我不的
# prefix-不分开:  不分开 我不不的 我不的 我不的 我不的 我不的 我不的 我不的 我不的 我不的 我不的 我不的 我不的
#
#
# Epoch [15/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 436.5688, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我的 我的 我的 我的 我的 我的 我的 我的 我的 我的 我的 我的 我的 我的 我的 我的 我
# prefix-不分开:  不分开 我的 我的 我的 我的 我的 我的 我的 我的 我的 我的 我的 我的 我的 我的 我的 我的 我
#
#
# Epoch [16/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 429.7460, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我不不我的我的 我的我的 我的我的 我的我的 我的我的 我的我的 我的我的 我的我的 我的我的 我
# prefix-不分开:  不分开 我不不我的我的 我的我的 我的我的 我的我的 我的我的 我的我的 我的我的 我的我的 我的我的 我
#
#
# Epoch [17/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss:
train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始不出 一直都停在 走是强度 我想要你的微笑每天都能看到  我知道这里很美但家乡的你更美 而过是你的
# prefix-不分开:  不分开 我不能再想 只想问你看家乡的地 再知么不要我 这些好久 不想要你就走 我不能再想 我不能再想 我不
#
#
# Epoch [182/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 25.5608, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始不出来 我不能再想 我不 我不 我不能 爱情走的太快就像龙卷风 不能承受我已无处可躲 我不能再想
# prefix-不分开:  不分开 我不能再想 我不 我不 我不能 爱情走的太快就像龙卷风 不能承受我已无处可躲 我不能再想 我不 我
#
#
# Epoch [183/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 25.2827, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始不停气 我不能再想 我不能再想 我不 我不 我不要再想你 不知不觉 你已经离开我 不知不觉 我跟了
# prefix-不分开:  不分开 我不能再想 我不能再想 我不 我不 我不要再想你 不知不觉 你已经离开我 不知不觉 我跟了这节奏
#
#
# Epoch [184/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 25.0021, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始不出来 被蓝的爱怎么 我用第一人称　在飘移青春 输跟赢的分寸　计算的很精准 我踏上风火轮　在飘移青
# prefix-不分开:  不分开 我在等 一堆 强 后出爱的 在飘里面上油 在我地盘这   你就得听我的 节奏在招惹   我跟街舞亲
#
#
# Epoch [185/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 24.7235, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始不出 你说我若一个人会比较自由 我不懂你们什么 我不是你的微笑变才了 我送我的自信 都有多烦能就算
# prefix-不分开:  不分开 我不能再想 我不能再想 我不 我不 我不要再想你 不知不觉 你已经离开我 不知不觉 我跟了这节奏
#
#
# Epoch [186/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 24.4527, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始不出 我永不能 一颗正酒 再来一碗热粥 配上几斤的牛肉 我说店小二 三两银够不够 景色入秋 漫天黄
# prefix-不分开:  不分开 我要一步一步往上爬 在最高点乘着叶片往前飞 小小的天流过的泪和汗 习惯 一箩两步三步四步望著天 看
#
#
# Epoch [187/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 24.1821, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我的爱溢出就象雨水 窗台蝴蝶 象诗里纷飞的美丽章节 我接着写 把永远爱你写进诗的结尾 你是我唯一想
# ...
#
#
# Epoch [189/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 23.6581, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 不要你离开 距离隔不开 思念变成海 在窗外进不来 原谅说太快 爱成了阻碍 手中的风筝在人距中 谁在
# prefix-不分开:  不分开 我不能再想 我不 我不 我不要再想你 不知不觉 你已经离开我 不知不觉 我跟了这节奏 后知后觉 后
#
#
# Epoch [190/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 23.3996, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始不出的情性 请你给你的美号 我的你说 再来 还有彩没出错  就连风吹都要干扰  可是你不想 一直走
# prefix-不分开:  不分开 我要一步一步往上爬 青色帘幕流的 征时是一个雨 我会亲手写上 晨曦的爱 不让自导自演自己 我真的没
#
#
# Epoch [191/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 23.1410, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始不出 你我把等雨小世 将后为了 全红的 不够了 爱淡了 梦远了 开心与不开心 一一细数着 你再不舍
# prefix-不分开:  不分开 我在等你来 电视板 的感觉 还好不同 也没道理 才能扑护她的心 我不配 这感觉已经不对我努力在挽回
#
#
# Epoch [192/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 22.8885, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始不出 你说我的眼泪 让它留在雨天 哦 越过你划的线 我定了勇气的终点 你说我不该不该 不该在这时候
# prefix-不分开:  不分开 我不能再想 我不能再想 我不 我不 我不能 爱情走的太快就像龙卷风 不能承受我已无处可躲 我不要再
#
#
# Epoch [193/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 22.6563, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始不知道不会 我不能再想 我不 我不 我不要再想你 爱情来的太快就像龙卷风 离不开暴风圈来不及逃 我
# prefix-不分开:  不分开 我不能再想 我不要再想 我不要再想 我不 我不 我不要再想你 爱情来的太快就像龙卷风 离不开暴风圈
#
#
# Epoch [194/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 22.4144, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始不出 这里都不得得 就要这样怎么抱　 你说不该再相见只为了瞬间 谢谢你让我听见 因为我在等待永远
# prefix-不分开:  不分开 我不能再想 我不能再想 我不 我不 我不要再想你 不知不觉 你已经离开我 不知不觉 我跟了这节奏
#
#
# Epoch [195/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 22.1782, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始不停是一天 如果说了太多 也许颓子都想分手牵你不回 来不及易笑 如果这种海力　算自己 他们猜看我猜
# prefix-不分开:  不分开 我不能再这样打着你的你 不知不来 你已经离开我 不知不觉 你跟王心 谁生小暴不 走得很分究 你说你
#
#
# Epoch [196/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 21.9463, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始不出 我说好好一路 一句两种三步四步望著天 看星星 一颗两颗三颗四颗 连成线背著背默默许下心愿 看
# prefix-不分开:  不分开 我在等 一堆序 后再开 不稀 你看很难默 我知道不能再留 你永远赢不了 我永远做不到 你永远赢不了
#
#
# Epoch [197/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 21.7130, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始不出我 就算这样的世界 往下風夜
# prefix-不分开:  不分开 我要一步一步往上爬 等待阳光静静看着它的脸 小小的天有大大的梦想 我想想你想像只有一点的回忆 你不
#
#
# Epoch [198/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 21.4882, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始不出我 我不是你们回忆的我更寻 你说好想像哭 手名最后一个字 作药風藏 我的爱溢出就象雨水 院子落
# prefix-不分开:  不分开 我在等你来 你加声黑 纷上放开 风声声霜 象一直都 我加格无力 一统江山 破城之后 我却微笑绝不恋
#
#
# Epoch [199/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 21.2656, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始不出我 我不要再想 我不要再想 我不 我不 我不要再想你 不知不觉 你已经离开我 不知不觉 我跟了
# prefix-不分开:  不分开 我要一步一步往上爬 在最高点乘着叶片往前飞 小小的天流过的泪和汗 习惯 一直在停我 泪不休 语沉默
#
#
# Epoch [200/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 21.0469, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始不出我 就不回来 那骄傲我 带着一生  胜果的消式 这里都有何密 我可以是微微的狗 再怎么接 音都
# prefix-不分开:  不分开 我在等 一堆 强练不停平 想念快一天 一身为山 雨一切 梦成了你 在你的怀里 在路上杆上的角望 在
#
#
# Epoch [201/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 20.8298, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始不出 你我用一把打我  口袋 那鲁湾 N火 停止忿恨 永无止尽的战争 让我们 半兽人 的灵魂 单纯
# prefix-不分开:  不分开 我在等 一堆 强练着为了太爱 我用心 你的好像我抱透 来不到你要一个歌 一根页不忍 心到那快 我一
#
#
# Epoch [202/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 20.6170, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始不出我 就算这样的说话 是因为我太爱你 要我说了 泪不甘的 能自己爱不了我 后才会别人  你叫风
# prefix-不分开:  不分开 我不要再想 我不要再想 我不 我不 我不要再想你 不知不觉 你已经离开我 不知不觉 我跟了这节奏
#
#
# Epoch [203/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 20.4183, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始不出来 你说我若一个人会比较自由 我不想拆穿你 当作 是你开的玩笑 想通 却又再考倒我 说散 你想
# prefix-不分开:  不分开 我不能再想 我不能再想 我不 我不 我不能 爱情走的太快就像龙卷风 不能承受我已无处可躲 我不要再
#
#
# Epoch [204/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 20.2186, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始不出我 就算这样的世界 当下自听到 还有了空虚 基于两种立场我会罩着你 趁时间没发觉 让我带着你离
# prefix-不分开:  不分开 我不能再想 我不能再想 我不 我不 我不要再想你 不知不觉 你已经离开我 不知不觉 我跟了这节奏
#
#
# Epoch [205/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 20.0204, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始打出手 在小村外的溪边 默默等待 娘子 一壶 重壮 的人 翻挡 收人 征战 弓箭 是谁的从前 喜欢
# prefix-不分开:  不分开 一列 超高速的地铁 一路 训练我的听觉 消灭 那些 太琐碎 太异类 让问题尖锐 Oh   一双 狂
#
#
# Epoch [206/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 19.8230, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始打手 别人可以 开始在雕刻   我个人的特色 未来难预测   坚持当下的选择 在我地盘这   你就
# prefix-不分开:  不分开 我不想就这样牵着你的手不放开 爱可不可以简简单单没有伤害 你 靠着我的肩膀 你 在我胸口睡著 像这
#
#
# Epoch [207/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 19.6341, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始打手 远方的风车 远距离诉说 那幸福在深秋 满满的被收割 老仓库的角落 我们数着 一麻袋的爱跟快乐
# prefix-不分开:  不分开 我在等你来 说你的宠子我有在重感动 我将那年满的那城声号 深埋在美索不达米亚平原 用楔形文字刻下了
#
#
# Epoch [208/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 19.4468, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始打手 人真的真的想知道 那首来自东欧的民谣 和弦到底什么调 米兰的天空刚破晓 他真的真的想知道 他
# prefix-不分开:  不分开 我不能再想 我不要再想 我不要再想 我不 我不 我不要再想你 不知不觉 你已经离开我 不知不觉 我
#
#
# Epoch [209/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 19.2570, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始不停 一直都没感 你 有些  好為 尖a 不要吵  摇滚不是為了把妹 是為了梦想 当然魅力太强 被
# prefix-不分开:  不分开 我不能再想 我不能再想 我不 我不 我不要再想你 不知不觉 你已经离开我 不知不觉 我跟了这节奏
#
#
# Epoch [210/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 19.0732, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始打手 远方的风车 远距离诉说 那幸福在深秋 满满的被收割 老仓库的角落 我们数着 一麻袋的爱跟快乐
# prefix-不分开:  不分开 我在等 一堆 强练不停   合  我们 功夫  赶一块Ice  Ice  叫他不要吵  不要吵
#
#
# Epoch [211/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 18.8899, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始打出 爱你穿越后视一个人伤 眼睛 娘子却依旧每日折一枝杨柳 在小村外的溪边河口 默默的在等著我 家
# prefix-不分开:  不分开 我不能再想 我不 我不 我不要再想你 不知不觉 你已经离开我 不知不觉 我跟了这节奏 后知后觉 又
#
#
# Epoch [212/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 18.7082, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始不出 你说我的爱情 被顺人还是 我们 在我 中只需要  你就得听我的 把音乐收割   用听觉找快乐
# prefix-不分开:  不分开 我不要再想 我不要再想 我不要再想 我不要再想 我不要再想 我不要再想 我不要再想 我不要再想 我
#
#
# Epoch [213/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 18.5286, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始打出 爱你穿越后视一许 听说的爱  还有你在我身多 说话的爱 不让自受自演眼泪 别人能不该去退 我
# prefix-不分开:  不分开 我不能再想 只有多烦就能听妈 没人帮着它走 你永远方 猜我习惯　你小小的脸 那在电话是你的样 我会
#
#
# Epoch [214/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 18.3494, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始打手 远方走愧 那阵骤雨 由不得你 如果生命 对每个人 都不公平 也没道理 那就让我 带着孤寂 继
# prefix-不分开:  不分开 我不能就这样失去你的微笑 口红待在桌脚 而你我找不到 若角色对调 你说好不好 你的笑 你的好 脑海
#
#
# Epoch [215/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 18.1713, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始打出 爱你穿越后转着 多少可以女人 单纯的白色 温暖中慈祥 听妈妈的话 别让她受伤 想快快长大 才
# prefix-不分开:  不分开 到底有什么我如何能够说 口感到了解药 用用古书的咒装像被卷色 我心到哪情会很好　 最美的爱情 回忆
#
#
# Epoch [216/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 18.0082, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始不出 你说把爱渐渐 放下会走更远 又何必去改变 已走过的时间 你用你的指尖 阻止我说再见 想象你在
# prefix-不分开:  不分开 我不能再想 我不 我不 我不要再想你 爱情来吃太快的 啊usic 在我地盘这   你就得听我的 节
#
#
# Epoch [217/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 17.8535, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始打出手出爱 我是否假有一点 你也慢慢在暗暗等来想看 想要有点堂机机 那么会扯去扯铃　 扯多你就会上
# prefix-不分开:  不分开 我不能再想 我不能再想 我不 我不 我不要再想你 爱情来的太快就像龙卷风 离不开暴风圈来不及逃 我
#
#
# Epoch [218/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 17.6904, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始打手 天真在这条路上 跌跌撞撞 他被芒草割伤 孩子们眼中的希望是什么形状 是否醒来有面包跟早餐 再
# prefix-不分开:  不分开 我在等你来 说你的宠色 问我怎么睡的小　 你笑了之后 不需要記得我。 燈熄的時候 滿天的星空 最明
#
#
# Epoch [219/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 17.5319, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始打出 爱没有了明白 到底还要飞出手 这样也好 但该不想 你的改变我能够分辨 我们就这样去 我们的爱
# prefix-不分开:  不分开 我只有一种的自量 自然的自己自己的爱不 过气 你的脸没属抱 沉默的听你撒娇 看你睡著一直到老 就是
#
#
# Epoch [220/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 17.3720, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始不出 这里都有不知道 不是因为在乎自己 我却在等待 将爱日出 一直在停留 谁让它停留的 为什么我女
# prefix-不分开:  不分开 我不想就这样一直走 心天的让我心疼的可爱女人 透明的让我感动的可爱女人 坏坏的让我疯狂的可爱女人
#
#
# Epoch [221/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 17.2207, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始出出 爱没有爱一行 我只是卑微的小丑 翻幾個跟斗 在等待 爱恨 从此不存太太多 这些 一件好 告诉
# prefix-不分开:  不分开 我只有一种的回忆 能不能给我一首歌的时间 紧紧的把那拥抱变成永远 在我的怀里你不用害怕失眠 哦 如
#
#
# Epoch [222/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 17.0654, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始不出 你说我若一个人会比较自由 我不懂你说什么 反正不会松手 我背你走到最后 能不能别想太多 会不
# prefix-不分开:  不分开 我不能再想 我不能再想 我不能再想 我不 我不 我不要再想你 不知不觉 你已经离开我 不知不觉 我
#
#
# Epoch [223/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 16.9193, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始不停 一角的色毛花 错出了眼泪 找不起谁来拆 我不能就这样失去你的微笑 口红待在桌脚 而你我找不到
# prefix-不分开:  不分开 我不能再想 我不能再想 我不 我不 我不要再想你 不知不觉 你已经离开我 不知不觉 我跟了这节奏
#
#
# Epoch [224/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 16.7711, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始不出 一直都好好 谁都有舍不 我的 我失去了谁说后知道不 说不到 面想再问一只飘移 那童年的希望是
# prefix-不分开:  不分开 我不能再想 我不能再想 我不 我不 我不要再想你 不知不觉 你已经离开我 不知不觉 我跟了这节奏
#
#
# Epoch [225/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 16.6235, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始打手 远方的风车 远距离诉说 那幸福在深秋 满满的被收割 老仓库的角落 我们数着 一麻袋的爱跟快乐
# prefix-不分开:  不分开 我不能就这样失去你的微笑 口红待在桌脚 而你我找不到 若角色对调 你说好不好 你的笑 你的好 脑海
#
#
# Epoch [226/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 16.4799, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始打出 爱你穿越过去 那么多余就怎么期　 却记得你说你发现 想象到你飞家电宙 面对海风蓝
# prefix-不分开:  不分开 我不想就这样牵着你的手不放开 爱可不可以简简单单没有伤害 你 靠着我的肩膀 你 在我胸口睡著 像这
#
#
# Epoch [227/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 16.3373, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始打出 爱你穿越时间 两行来自秋末的眼泪 让爱渗透了地面 我要的只是你在我身边 轻轻的叹息  后悔着
# prefix-不分开:  不分开 我在等待 画面序 我辈子 再来一口 拯救了 清晰的 一切 时光机 你我翻滚 的小巷 背下一台 在感
#
#
# Epoch [228/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 16.1948, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始不停 一角的时候 整头也还在等待 以为你还会回来 你的脸慢慢离开 时间快将我掩埋 消失得太快 我负
# prefix-不分开:  不分开 我不用豆腐e下的夜 在我地盘这   你就得听我的 节奏在招惹   我跟街舞亲热 我灌溉原则   培
#
#
# Epoch [229/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 16.0584, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始打出 爱没有爱女人 不要你离开 距离隔不开 思念变成海 在窗外进不来 原谅说太快 爱成了阻碍 手中
# prefix-不分开:  不分开 我不要再这一场 想要而你回来 你说我若一个人会比较自由 我不懂你说什么 反正不会松手 我背你走到最
#
#
# Epoch [230/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 15.9202, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我的世界 你不在里面 我的指尖 已经弹出茧 还是无法留你在我身边 断了的弦 再怎么练 我的感觉 你
# prefix-不分开:  不分开 我不要再这一场 我的世界 你不在里面 我的指尖 已经弹出茧 还是无法留你在我身边 断了的弦 再怎么
#
#
# Epoch [231/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 15.7874, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 爱情不该让苦书 这样会要过多 没关系太多  没有结尾  憔悴后悔等等这些 於是我把诗摺叠 邮寄出感
# prefix-不分开:  不分开 我不能就这样失得你的想我 在原暗来好暗 啦啦啦啦啦啦 妖兽扰乱人间秩序 血腥如浪潮般来袭 我小命差
#
#
# Epoch [232/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 15.6548, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始打手 人真的没  还是会微微手 我手中你 人魔开始重出地狱 叛军如野火般攻击 五官差点离开身体 还
# prefix-不分开:  不分开 我不要再这一场的我们 在我的重堡 在月光着来找找到 再也没有纯白的灵魂 自人类堕落为半兽人 我开始
#
#
# Epoch [233/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 15.5228, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我的世界将被摧毁 也许颓废也是另一种美 也许颓废也是另一种美 也许颓废也是另一种美 也许颓废也是另
# prefix-不分开:  不分开 我不能再想 我不 我不 我不要再想你 不知不觉 你已经离开我 不知不觉 我跟了这节奏 后知后觉 又
#
#
# Epoch [234/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 15.3960, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始打开 我没有这种天份 包容你也接受他 不用担心的太多 我会一直好好过 你已经远远离开 我也会慢慢走
# prefix-不分开:  不分开 我不能再想 我不 我不 我不能 爱情走的太快就像龙卷风 不能承受我已无处可躲 我不要再想 我不 我
#
#
# Epoch [235/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 15.2671, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始打出 爱没有爱太爱 只是我现在最顶　 雨下了　赖只能等你来 还有没有 知道好人 直着吗 痛了一步武
# prefix-不分开:  不分开 我在等待 画面序暴风 在等待 残洛的公式我学不来 我闻不到腐烂的香味 说不我很後悔当时没有这样的肯
#
#
# Epoch [236/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 15.1451, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始打手 远方的风车 远距离诉说 那幸福在深秋 满满的被收割 老仓库的角落 我们数着 一麻袋的爱跟快乐
# prefix-不分开:  不分开 我不能再想 我不能再想 我不 我不 我不要再想你 不知不觉 你已经离开我 不知不觉 我跟了这节奏
#
#
# Epoch [237/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 15.0207, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始打开 爱的爱 梦境的 一切 到光失 你是别还在 琴声何来 生死难猜 用一生去等待 我说的花 妈妈的
# prefix-不分开:  不分开 我不能就这样失去你的微笑 口红待在桌脚 而你我找不到 若角色对调 你说好不好 说了再见 才发现再也
#
#
# Epoch [238/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 14.8958, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始打手 远方的风车 远距离诉说 那幸福在深秋 满满的被收割 老仓库的角落 我们数着 一麻袋的爱跟快乐
# prefix-不分开:  不分开 我在等你话里着村奶 娘子们眼中的希望 一定 旧旧的可笑  只能看见到哪 我真的不该　不该 简单一句
#
#
# Epoch [239/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 14.7728, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我要我 装我有多难熬  也许你微单车 我想就这样牵着你的手不放开 爱可不可以简简单单没有伤害 你
# prefix-不分开:  不分开 我不能再想 我不能再想 我不 我不 我不要再想你 不知不觉 你已经离开我 不知不觉 我跟了这节奏
#
#
# Epoch [240/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 14.6525, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 爱情不该让苦了 你说啊 你怎么抄我球 你说啊 你怎么打我手 你说啊 是不是你不想活 说你怎么面对我
# prefix-不分开:  不分开 我不能就这样忍着痛泪不掉 说好陪我到老 永恒往哪里找 再次拥抱 一分一秒都好 天凉了 雨下了 你走
#
#
# Epoch [241/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 14.5353, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始不停 一角色的日惑 谁怎么都 我却将爱情更跳家 为什么这种速度你追不到 坐着生命就该完整动 为什么
# prefix-不分开:  不分开 我不要再想 我不要再想 我不 我不 我不要再想你 爱情来的太快就像龙卷风 离不开暴风圈来不及逃 我
#
#
# Epoch [242/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 14.4204, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始不出 你说我若一个人会比较自由 我不懂你说什么 反正不会松手 我背你走到最后 能不能别想太多 会不
# prefix-不分开:  不分开 我不能再想 我不能再想 我不 我不 我不要再想你 不知不觉 你已经离开我 不知不觉 我跟了这节奏
#
#
# Epoch [243/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 14.3038, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始打出 接着大家是否是大人们 难过是一只会说法语因為优雅的猪 吸血前会念约翰福音做为弥补 拥有一双蓝
# prefix-不分开:  不分开 我在等你话里说出方生 阴惧回来到他的样子冷妈的离地 在空中忘了前进 还能不能 重新编织 脑海中起毛
#
#
# Epoch [244/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 14.1896, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始不停 一角的时候 谁都没有别人全 说再见到过多 如果要走 请你记得我 翻着我们的照片 想念若隐若现
# prefix-不分开:  不分开 我不能输 我只想要你 一路有种悲励 会觉得你更傻  没有结尾  憔悴后悔等等这些 於是我把诗摺叠
#
#
# Epoch [245/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 14.0757, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始打手 别人们根败 所有的悲傷統統了了 真有的重却在 神里 对着 消失的手 不对你看得 那么 我有拥
# prefix-不分开:  不分开 我不能输 我没有紧紧抱住你 你说泪留着 狠危险 如果等雨一起  等雨一起  流下不让同情发现 我对
#
#
# Epoch [246/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 13.9702, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始不停 一角色时候 一群嗜血的螞蟻飘 那最后视　 有没有口罩一个给我　 释怀说了太多就成真不了 也许
# prefix-不分开:  不分开 我不用听你的小心 你站的方位 跟我中间隔着泪 街景一直在后退 你的崩溃在窗外零碎 我一路向北 离开
#
#
# Epoch [247/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 13.8599, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始视出 我没有这种天份 包容你也接受他 不用担心的太多 我会一直好好过 你已经远远离开 我也会慢慢走
# prefix-不分开:  不分开 我在等你话里有属的你最美的可爱女人 温柔的让我心疼的可爱女人 透明的让我感动的可爱女人 坏坏的让我
#
#
# Epoch [248/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 13.7495, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始不出的情 一天的名一笑 打化了再走 我突然释怀地笑 笑声盘旋半山腰 随风在飘摇啊摇 来到你的面前绕
# prefix-不分开:  不分开 我在等你来 说你的事完 收着放开　 过往的冬天 我们数着 走过过 才不用麻烦了 不用麻烦了 你们一
#
#
# Epoch [249/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 13.6428, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始打手 别人们看不到 我永远做不到 你永远赢不了 永远都赢不了 走下乡寻找哪有花香 为什么这么简单你
# prefix-不分开:  不分开 我不用豆腐 豆腐  豆腐 豆腐  我在武功学校里学的那叫功夫 功夫 功夫  功夫 功夫  赶紧穿上
#
#
# Epoch [250/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 13.5425, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始打手 人真的真的想知道 那首来自东欧的民谣 和弦到底什么调 米兰的天空刚破晓 他真的真的想知道 他
# prefix-不分开:  不分开 我不能就这样失去你的微笑 口红待在桌脚 而你我找不到 若角色对调 你说好不好 你的笑 你的好 脑海

# %% [markdown]
# ### 简单实现

# %% [markdown]
# #### 网络定义

# %%
class RNNModel(nn.Module):
    def __init__(self, rnn_layer, vocab_size):
        super(RNNModel, self).__init__()
        self.rnn = rnn_layer
        self.hidden_num = self.rnn.hidden_size * (2 if self.rnn.bidirectional else 1)
        self.vocab_size = vocab_size
        self.fc = nn.Linear(hidden_num, vocab_size)
        self.h_state = None
        
    def forward(self, x, h_state):
        # x.shape is (num_step, batch_size, vocab_size)
        y, self.h_state = self.rnn(x, h_state)
        return self.fc(y), self.h_state

# %% [markdown]
# #### 预测

# %%
def predict_rnn_pytorch(prefix, pred_num, model, char_to_idx, vocab_set, vocab_size, device):
    outputs = [char_to_idx[prefix[0]]]
    h_state = None
    
    for i in range(len(prefix) + pred_num - 1):
        inputs = to_onehot(torch.tensor(outputs[-1]).view(-1, 1), vocab_size, device)
        if h_state is not None:
            if isinstance(h_state, tuple): # lstm , (h,c)
                h_state = (h_state[0].to(device), h_state[1].to(device))
            else:
                h_state = h_state.to(device)
                
        y, h_state = model(inputs, h_state)
        if i + 1 < len(prefix):
            outputs.append(char_to_idx[prefix[i+1]])
        else:
            outputs.append(y.argmax(dim=2).item())
            
    return "".join(vocab_set[i] for i in outputs)

# %%
# 验证
# load data
hidden_num = 256
corpus_index, char_to_idx, vocab_set, vocab_size = load_data_jay_song()
rnn_layer = nn.GRU(vocab_size, hidden_num)
model = RNNModel(rnn_layer, vocab_size)
model = model.cuda()
predict_rnn_pytorch("分开", 10, model, char_to_idx, vocab_set, vocab_size, "cuda")
# Out:
# '分开稳睫奇跑跑得睫跑跑跨'

# %% [markdown]
# #### 训练

# %%
# training
import numpy as np
from sqdm import sqdm
from optim import sgd

def train_rnn_pytorch(epoch_num, batch_num, model, loss, optimizer, batch_size, data_iter, prefixs, 
                      pred_num, corpus_index, char_to_idx, vocab_set, vocab_size, num_step, predict_rnn_pytorch, 
                      clipping_theta=1e-2, random_sample=True, device="cuda"):
    
    # init(use in calculate perplexity)
    l_sum, n_class = 0., 0.
    # training bar
    process_bar = sqdm()
    
    for epoch in range(epoch_num):
        print(f"Epoch [{epoch+1}/{epoch_num}]")
        # sample in consecutive
        if not random_sample:
            h_state = None
        for x, y in data_iter(corpus_index, batch_size, num_step, device):
            # 原始x的shape为(batch_size, num_step)，onehot后的shape为(num_step, batch_size, vocab_size)
            x = to_onehot(x, vocab_size, device)
            if random_sample:
                h_state = None
            else:
                # 脱离计算图，使得上一时刻的隐藏状态变成叶子节点，防止在销毁计算图后（隐藏节点还存在），因反向传播到更早的
                # 隐藏层时刻（不在当前计算图内）而出错
                if h_state is not None:
                    if isinstance(h_state, tuple): # lstm, state: (h, c)
                        h_state = (h_state[0].detach(), h_state[1].detach())
                    else:
                        h_state.detach_()
                
            # model
            # outputs.shape is (num_step, batch_size, vocab_size), h_state.shape is (batch_size, hidden_num)
            outputs, h_state = model(x, h_state)
            # change output.shape --> (num_step, batch_size, vocab_size), 主要是为了方便计算loss
            outputs = outputs.view(-1, outputs.shape[-1])
            # 原始y的shape为(batch_size, num_step), ---> (num_step, batch_size) ---> 1维向量
            # 转置后变成内存不连续，使用contiguous变成连续的向量
            y = y.transpose(0, 1).contiguous().view(-1)
            
            # 计算loss, 标签需要是int
            l = loss(outputs, y.long())
            # grad clear
            optimizer.zero_grad()
            # grad backward
            l.backward()
            # grad clipping
            grad_clipping(model.parameters(), clipping_theta, device)
            # update grad
            optimizer.step()
            
            # calculate l_sum
            l_sum += l.item() * y.shape[0]
            n_class += y.shape[0]
            
            # calculate perplexity
            try:
                perplexity = np.exp(l_sum / n_class)
            except OverflowError:
                perplexity = float("inf")
                
            # training bar
            process_bar.show_process(batch_num, 1, perplexity)
        print("\n")
        # predict
        for prefix in prefixs:
            print(f"prefix-{prefix}: ", predict_rnn_pytorch(prefix, pred_num, model, char_to_idx, vocab_set, vocab_size, device))
        print("\n")

# %%
hidden_num = 256
rnn_layer = nn.GRU(vocab_size, hidden_num)
model = RNNModel(rnn_layer, vocab_size)
model = model.cuda()
loss = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

params = {
    "epoch_num": 250,
    "model": model,
    "loss": loss,
    "optimizer": optimizer,
    "batch_size": 64,
    "num_step": 32,
    "corpus_index": corpus_index,
    "data_iter": data_iter_random,
    "char_to_idx": char_to_idx,
    "vocab_set": vocab_set,
    "vocab_size": vocab_size,
    "predict_rnn_pytorch": predict_rnn_pytorch,
    "pred_num": 50,
    "prefixs": ["分开", "不分开"],
#     "random_sample": False
}

params["batch_num"] = len(list(data_iter_random(corpus_index, params["batch_size"],
                                                     params["num_step"], "cpu")))

train_rnn_pytorch(**params)
# Out:
# Epoch [1/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 923.6031, train_score: -, test_loss: -, test_score: --
#
# prefix-分开:  分开
# prefix-不分开:  不分开
#
#
# Epoch [2/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 640.9834, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开
# prefix-不分开:  不分开
#
#
# Epoch [3/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 556.9185, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开
# prefix-不分开:  不分开
#
#
# Epoch [4/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 512.9613, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开
# prefix-不分开:  不分开
#
#
# Epoch [5/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 482.1536, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开  我  我  我  我  我  我  我  我  我  我  我  我  我  我  我  我
# prefix-不分开:  不分开  我  我  我  我  我  我  我  我  我  我  我  我  我  我  我  我
#
#
# Epoch [6/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 456.5853, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我
# prefix-不分开:  不分开 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我 我
#
#
# Epoch [7/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 432.5120, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我的我 我的我 我的我 我的我 我的我 我的我 我的我 我的我 我的我 我的我 我的我 我的我 我
# prefix-不分开:  不分开 我的我 我的我 我的我 我的我 我的我 我的我 我的我 我的我 我的我 我的我 我的我 我的我 我
#
#
# Epoch [8/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 409.1464, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我的我的 我的我的 我的我的 我的我的 我的我的 我的我的 我的我的 我的我的 我的我的 我的我的
# prefix-不分开:  不分开 我的我的 我的我的 我的我的 我的我的 我的我的 我的我的 我的我的 我的我的 我的我的 我的我的
#
#
# Epoch [9/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 386.5203, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我的我的 我的我的 我的我的 我的我的 我的我的 我的我的 我的我的 我的我的 我的我的 我的我的
# prefix-不分开:  不分开 我的我的 我的我的 我的我的 我的我的 我的我的 我的我的 我的我的 我的我的 我的我的 我的我的
#
#
# Epoch [10/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 364.5625, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我不能不是我的我的我 我的我的我 我的我的我 我的我的我 我的我的我 我的我的我 我的我的我 我的
# prefix-不分开:  不分开 我的我的我 我的我的我 我的我的我 我的我的我 我的我的我 我的我的我 我的我的我 我的我的我 我
#
#
# Epoch [11/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 343.2700, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我们的天  我们的天  我们的天  我们的天  我们的天  我们的天  我们的天  我们的天  我
# prefix-不分开:  不分开 我们的天  我们的天  我们的天  我们的天  我们的天  我们的天  我们的天  我们的天  我
#
#
# Epoch [12/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 323.1030, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我们的爱 我们的爱 我们的爱 我们的爱 我们的爱 我们的爱 我们的爱 我们的爱 我们的爱 我们的爱
# prefix-不分开:  不分开 我们的爱 我们的爱 我们的爱 我们的爱 我们的爱 我们的爱 我们的爱 我们的爱 我们的爱 我们的爱
#
#
# Epoch [13/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 303.8823, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我们的爱情 我们的爱情 我们的爱情 我们的爱情 我们的爱情 我们的爱情 我们的爱情 我们的爱情 我
# prefix-不分开:  不分开 我们的爱情 我们的爱情 我们的爱情 我们的爱情 我们的爱情 我们的爱情 我们的爱情 我们的爱情 我
#
#
# Epoch [14/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 285.7645, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我们的爱情 我们的爱情 我们的爱情 我们的爱情 我们的爱情 我们的爱情 我们的爱情 我们的爱情 我
# prefix-不分开:  不分开 我们的爱情 我们的爱情 我们的爱情 我们的爱情 我们的爱情 我们的爱情 我们的爱情 我们的爱情 我
#
#
# Epoch [15/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 268.7334, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我不能不到 我不能不到 我不能不到 我不能不到 我不能不到 我不能不到 我不能不到 我不能不到 我
# prefix-不分开:  不分开 我不能不到 我不能不到 我不能不到 我不能不到 我不能不到 我不能不到 我不能不到 我不能不到 我
#
#
# Epoch [16/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 252.7247, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我们的爱情 我们的爱情 我们的爱情 我们的爱情 我们的爱情 我们的爱情 我们的爱情 我们的爱情 我
# prefix-不分开:  不分开 我们的爱情 我们的爱情 我们的爱情 我们的爱情 我们的爱情 我们的爱情 我们的爱情 我们的爱情 我
#
#
# Epoch [17/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 237.7557, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我不能不能不能不能不能不能不能不能不能不能不能不能不能不能不能不能不能不能不能不能不能不能不能不能
# prefix-不分开:  不分开 我不能不能不能不能不能不能不能不能不能不能不能不能不能不能不能不能不能不能不能不能不能不能不能不能
#
#
# Epoch [18/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 223.8307, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我们的爱情 我们的爱情 我们的爱情 我们的爱情 我们的爱情 我们的爱情 我们的爱情 我们的爱情 我
# prefix-不分开:  不分开 我们的爱情 我们的爱情 我们的爱情 我们的爱情 我们的爱情 我们的爱情 我们的爱情 我们的爱情 我
#
#
# Epoch [19/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 210.8154, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我不能不能 我不能不能 我不能不能 我不能不能 我不能不能 我不能不能 我不能不能 我不能不能 我
# prefix-不分开:  不分开 我不能不能 我不能不能 我不能不能 我不能不能 我不能不能 我不能不能 我不能不能 我不能不能 我
#
#
# Epoch [20/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 198.7220, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我不能够不到 我不能不要 我不能不要 我不能不要 我不能不要 我不能不要 我不能不要 我不能不要
# prefix-不分开:  不分开 我不能够不到 我不能不要 我不能不要 我不能不要 我不能不要 我不能不要 我不能不要 我不能不要
#
#
# Epoch [21/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 187.5147, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我不能不能 我不能不能 我不能不能 我不能不能 我不能不能 我不能不能 我不能不能 我不能不能 我
# prefix-不分开:  不分开 我不能不能 我不能不能 我不能不能 我不能不能 我不能不能 我不能不能 我不能不能 我不能不能 我
#
#
# Epoch [22/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 177.0571, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我们的眼泪 我们的眼泪 我们的眼泪 我们的眼泪 我们的眼泪 我们的眼泪 我们的眼泪 我们的眼泪 我
# prefix-不分开:  不分开 我们的眼泪 我们的眼泪 我们的眼泪 我们的眼泪 我们的眼泪 我们的眼泪 我们的眼泪 我们的眼泪 我
#
#
# Epoch [23/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 167.3798, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我
# prefix-不分开:  不分开 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我
#
#
# Epoch [24/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 158.3387, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我不能不能 我不能不能 我不能不能 我不能不能 我不能不能 我不能不能 我不能不能 我不能不能 我
# prefix-不分开:  不分开 我不能不能 我不能不能 我不能不能 我不能不能 我不能不能 我不能不能 我不能不能 我不能不能 我
#
#
# Epoch [25/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 149.9631, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我们的眼泪 我们的眼泪 我们的眼泪 我们的眼泪 我们的眼泪 我们的眼泪 我们的眼泪 我们的眼泪 我
# prefix-不分开:  不分开 我们的眼泪 我们的眼泪 我们的眼泪 我们的眼泪 我们的眼泪 我们的眼泪 我们的眼泪 我们的眼泪 我
#
#
# Epoch [26/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 142.1894, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我不能再想 你说不见 你说不见 你说不见 你说不见  我不能再想 你说不见 你说不见  我不能再想
# prefix-不分开:  不分开 我不能再想 你说不见 你说不见 你说不见  我不能再想 你说不见 你说不见  我不能再想 你说不见
#
#
# Epoch [27/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 134.9266, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我
# prefix-不分开:  不分开 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我
#
#
# Epoch [28/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 128.1613, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我不能再想 我不能再想 我不能再想 我不能再想 我不能再见 你说你的爱情 我不能再想 我不能再见
# prefix-不分开:  不分开 我不能再想 我不能再想 我不能再想 我不能再见 你说你的爱情 我不能再想 我不能再见 你说你的爱情
#
#
# Epoch [29/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 121.8744, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我不能够不到 我不能够不到 我不能够不到 我不能够不到 我不能够不到 我不能够不到 我不能够不到
# prefix-不分开:  不分开 你说你不能再想 你说你的爱情 我们都不到  我不能够不到 我不能够不到 我不能够不到 我不能够不到
#
#
# Epoch [30/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 116.0113, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我不能再想 你说你的爱情 我的爱情 我们都没有  我不能再想 你说你 我不能再想 你说你的爱情 我
# prefix-不分开:  不分开 一直在我的爱情 我们都没有  我不能再想 你说你 我不能再想 你说你的爱情 我的爱情 我不能再想
#
#
# Epoch [31/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 110.4918, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我不能再想 你说你的爱情 我的眼泪 我不能再想 你说你的爱情 我的眼泪 我不能再想 你说你的爱情
# prefix-不分开:  不分开 我不能再想 你说你的爱情 我的眼泪 我不能再想 你说你的爱情 我的眼泪 我不能再想 你说你的爱情
#
#
# Epoch [32/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 105.3335, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我不要再想 你说你 我不能再想 我不要
# prefix-不分开:  不分开 我不能再想 我不能再想 我不能再想 我不要再想 你说你 我不能再想 我不要再想 你说你 我不能再想
#
#
# Epoch [33/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 100.5102, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我不能再想 我不要再想 你说不到  我不能再想 我不要再想 你说不到  我不能再想 我不要再想 你
# prefix-不分开:  不分开 我不能再想 我不要再想 你说不到  我不能再想 我不要再想 你说不到  我不能再想 我不要再想 你
#
#
# Epoch [34/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 95.9812, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我
# prefix-不分开:  不分开 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我
#
#
# Epoch [35/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 91.7389, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我
# prefix-不分开:  不分开 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我
#
#
# Epoch [36/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 87.7533, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我不能再想 我不要再想 我不要再想 我不要再想 我不要再想 我不要再想 我不要再想 我不要再想 我
# prefix-不分开:  不分开 一定一直在 我们的感觉 我不能再想 我不要再想 我不要再想 我不要再想 我不要再想 我不要再想 我
#
#
# Epoch [37/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 83.9886, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我不能再想 我不要再想 你说你不会 我不要再想 你说不到  我不能再想 我不要再想 你说不出来
# prefix-不分开:  不分开 一直在我的天空 我用眼睛的天堂景象 我的爱溢出就象雨水 我 我不能再想 我不要再想 你说你不会 我
#
#
# Epoch [38/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 80.4507, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我不能再想 我不要再想 你说你不会 我想要你 我不能再想 我不要再想 你说了吧 我知道 我的爱情
# prefix-不分开:  不分开 我不能再想 我不要再想 你说了吧 我知道你的笑容 想要再回 你的爱情 我们的世界 不用麻烦了 不用
#
#
# Epoch [39/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 77.1198, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我不能再想 我不要再想 你说你不用麻烦了 不用麻烦了 不用麻烦了 不用麻烦了 不用麻烦了 不用麻烦
# prefix-不分开:  不分开 我不能再想 我不要再想 你说你不用麻烦了 不用麻烦了 不用麻烦了 不用麻烦了 不用麻烦了 不用麻烦
#
#
# Epoch [40/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 73.9621, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我不能再想 我不要再想 你说你不会 我说你不会 我会更自由 我 你说你不会 我说你不会 我会更自由
# prefix-不分开:  不分开 一直在我的天空 我会不会感到更加沮丧   我不能再想 我不要再想 你说你不会 我说你不会 我会更自
#
#
# Epoch [41/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 70.9841, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我不能再想 我不要再想 我不要再想 我不要再想 我不要再想 我不要再想 我不要再想 我不要再想 我
# prefix-不分开:  不分开 我不能再想 我不要再想 我不要再想 我不要再想 我不要再想 我不要再想 我不要再想 我不要再想 我
#
#
# Epoch [42/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 68.1737, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我不能再想 我不要再想 我不要再想 我不要再想 我不要再想 我不要再想 我不要再想 我不要再想 我
# prefix-不分开:  不分开 没有了空 我知道你的笑容 就算放弃了  不用麻烦了 不用麻烦了 不用麻烦了 不用麻烦了 不用麻烦了
#
#
# Epoch [43/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 65.4989, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我不能再想 我不要再想 我不要再想 我不要再想 我不要再想 你说了 不用麻烦了 不用麻烦了 不用麻
# prefix-不分开:  不分开 没有了解 你说了解 一起旅行　 我们的感觉 我不能再想 我不要再想 你说了 不用麻烦了 不用麻烦了
#
#
# Epoch [44/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 62.9659, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我不能够分手 我不能再想 我不要再想 你不会 我也没有了 不用麻烦了 不用麻烦了 不用麻烦了 不用
# prefix-不分开:  不分开 没有了空 我们的感觉 我不能再想 我不要再想 你不会 我也没有了 不用麻烦了 不用麻烦了 不用麻烦
#
#
# Epoch [45/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 60.5526, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我不能再想 我不要再想 我不要再想 我不要再想 我不要再想 我不要再想 我不要再想 我不要再想 我
# prefix-不分开:  不分开 没有了解 你说的爱我 我不能再想 我不要再想 我不要再想 我不要再想 我不要再想 我不要再想 我不
#
#
# Epoch [46/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 58.2821, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我不能再想 我不要再想 我不要再想 我不要再想 我不要再想 我不要再想 我不要再想 我不要再想 我
# prefix-不分开:  不分开 没有了空 我知道你的笑容 就算放开 只是我不能再想 我不要再想 我不要再想 我不要再想 我不要再想
#
#
# Epoch [47/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 56.1148, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我不能再想 我不想 你说你不用  一定一种独特  只是我的兄弟 都不公平 也没道理 没有了解释 我
# prefix-不分开:  不分开 没有了空气 我的眼神 我们都没有 我想要的让我们乘着阳光　 我用第一人称在飘移青春  他们在空中
#
#
# Epoch [48/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 54.0517, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我不能再想 我不要再想 我不要再想 我不要再想 我不要再想 我不要再想 我不要再想 我不要再想 我
# prefix-不分开:  不分开 没有了空气 我不要再想 我不要再想 我不要再想 我不要再想 我不要再想 我不要再想 我不要再想 我
#
#
# Epoch [49/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 52.0966, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 我不能够分辨 我不要再想 我不要再想 我不要再想 我不要再想 我不要再想 我不要再想 我不要再想
# prefix-不分开:  不分开 没有了空气 我的眼泪 我一定实现在这种天份 包容你就会开心的 我在等你 一定实现在这种天份 包容你
#
#
# Epoch [50/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 50.2247, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 只是我不能再想 我不要再想 我不要再想 我不要再想 我不要再想 我不要再想 我不要再想 我不要再想
# prefix-不分开:  不分开 只是我不能再想 我不要再想 我不要再想 我不要再想 我不要再想 我不要再想 我不要再想 我不要再想
#
#
# Epoch [51/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 48.4570, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 天空是谁的美丽 你的爱情只剩下一种 等待英雄 我的微笑　 我用第一人称 在等烟雨水 我在等待救援
# prefix-不分开:  不分开 没有了空 我知道 我的感觉 你已经离开我 我不能 我 你 我不能 我 你不会 我一定 我的手 我不
#
#
# Epoch [52/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 46.7747, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 天空是什么  我们 一直走到  我不想 你不会 让我们乘着阳光　 看着我的手经过 一直走 我不要再
# prefix-不分开:  不分开 没有了空 我知道 我的感觉 你不会感到更加沮丧   我 我不能 分手说不出来  我不想  你不会
#
#
# Epoch [53/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 45.1704, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 天空是谁的美丽 你的爱情只剩下一种 等待英雄 我 想起上谁的终场 我等待苍老了谁 红尘醉 微醺的岁
# prefix-不分开:  不分开 爱你的爱情只有一点秀逗 猎物死了它一颗两颗三颗四颗 连成线背著背默默许下心愿 看远方的风车 跟我看
#
#
# Epoch [54/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 43.6363, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 只是我不想再见 你的泪 在我面红的可爱女人 坏坏的让我疯狂的可爱女人 坏坏的让我疯狂的可爱女人 坏
# prefix-不分开:  不分开 没有了证明 没有你的手 就算没有了证明 没有你的手 在我心碎没人 你不会感到更加沮丧   不是 不
#
#
# Epoch [55/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 42.1668, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 天空是什么 别人的让我 想和你回忆 不用麻烦了 不用麻烦了 不用麻烦了 不用麻烦了 不用麻烦了 不
# prefix-不分开:  不分开 没有了解 你说好好 我不要再想 我不要再想 我不要再想 我不要再想 我不要再想 我不要再想 我不要
#
#
# Epoch [56/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 40.7821, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 只是我不想要你的手 就算没有错情 如果你想想要走 那些爱你的爱情 我一路向北 离开有一种味道叫做家
# prefix-不分开:  不分开 是因为我没有你说泪 是我们乘着阳光　 看着我的笑容你说你 我不想你 你说我的手 我会更自己主导　决
#
#
# Epoch [57/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 39.4471, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 天使的双截棍 哼哼哈兮 快使用双截棍 哼哼哈兮 快使用双截棍 哼哼哈兮 快使用双截棍 哼哼哈兮 快
# prefix-不分开:  不分开 没有了空气 还是会不会哭 一只有些 只是我不能再想 我不要再想 我不了 你说好 我不能再想 我不想
#
#
# Epoch [58/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 38.1686, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 只是我不想要你的手 我不想要 你说你好累 已经不出我的手 再次 听妈妈的话 别让我知道 想要你是我
# prefix-不分开:  不分开 是因为我没有你说不出来  我不能再想 我不想 你说你不用麻烦了 不用麻烦了 不用麻烦了 不用麻烦了
#
#
# Epoch [59/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 36.9407, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 天使的双截棍 哼哼哈兮 快使用双截棍 哼哼哈兮 快使用双截棍 哼哼哈兮 快使用双截棍 哼哼哈兮 快
# prefix-不分开:  不分开 是因为我没有你说不出来  不是我们 我们 半兽人 的灵魂 翻滚 停止忿恨 永无止尽的 娘子她人在江
#
#
# Epoch [60/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 35.7752, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 只是我不想再见 你的时间 我不想要你的手 如果我遇见你是一场悲剧 我想想这样 我不要再想 我不了
# prefix-不分开:  不分开 没有了证明 没有你的手 就算没有没有 我知道你离开有一点秀逗 猎物死了它也许命运的签 只让我们乘着
#
#
# Epoch [61/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 34.6645, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开始重出手
train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你会不会懂不懂事做 我也离不能再牵手不去 我去了吧 我知道你不会怎么会 你说不出手 海鸟跟鱼
# prefix-不分开:  不分开 没有爱过的 清楚了 我爱  麦搁一个人咧生气 乎伊烦恼 乎伊操心 虽然不关我的代誌 谁叫他是我的兄
#
#
# Epoch [132/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 8.3261, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你会更难过 你发如雪 凄美了离别 我焚香感动了谁 邀明月 让回忆皎洁 爱在月光下完美 你发如
# prefix-不分开:  不分开 没有你 我不想 我不再一个人手 在我胸口睡著 像这样的生活 我爱你 你爱我 我不是你爸 我会陪我手
#
#
# Epoch [133/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 8.2244, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你会不会懂事你不了 不好笑 为什么这样子 你拉着我 说你有些犹豫 怎么这样子 雨还没停你就撑
# prefix-不分开:  不分开 爱上 是谁说没有错 而你却已走不到 如果你在我 觉得自己写这份爱 把我在等待 读完了依赖 我很快就
#
#
# Epoch [134/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 8.1263, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你会不会懂事你累 已经远远离开 我也不是你 我不要再想 我不 我不 我不要再想 我不 我不
# prefix-不分开:  不分开 爱深埋珊瑚海  周杰伦  毁坏的沙雕如何重来 有裂痕的爱怎么重盖 只是一切 结束太快 你说的爱情
#
#
# Epoch [135/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 8.0296, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你会不会懂得更难过多少了 默契无法伪造 我们同一种调调　 不关心天气预报　因为那无关紧要 想
# prefix-不分开:  不分开 爱深埋珊瑚海  周杰伦  毁坏的沙雕如何重来 说穿过那些斷 在小村外的溪边河口 默默的在等著我 家
#
#
# Epoch [136/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 7.9350, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你说你好累 已无法再爱上谁 风在山路吹 过往的画面 全都是我不对 细数惭愧我伤你几回 停止狼
# prefix-不分开:  不分开 爱上 是谁来拆穿越 那掌 他真的 不能再想 我不 我不 我不能 爱情走的太快就像龙卷风 不能承受我
#
#
# Epoch [137/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 7.8416, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你说你好累 已无法再爱上谁 风在山路吹 过往的画面 全都是我不对 细数惭愧我伤你几回 我一路
# prefix-不分开:  不分开 爱上 是谁说 是不开 这不是我有了证明 没有了空虚 基于两种立场我会罩着你 趁时间没发觉 让我带着
#
#
# Epoch [138/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 7.7525, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你说你好累 已无法再爱上谁 风在山路吹 过往的画面 全都是我不对 细数惭愧我伤你几回 后视镜
# prefix-不分开:  不分开 没人能说再给我 我会陪你去 你继续前 我手中那张脸 缓缓飘落的枫叶像思念 为何挽回要赶在冬天来之前
#
#
# Epoch [139/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 7.6646, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你会不会懂得更自由 你要离开一起长大的约定　 那样清晰　打过勾的我相信 说好要一起旅行　 是
# prefix-不分开:  不分开 爱深埋珊瑚海  周杰伦  毁坏的沙雕如何重来 说穿了其实我的愿望就怎么小 就怎么每天祈祷我的心跳你
#
#
# Epoch [140/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 7.5779, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 心愿你把距离吹得好远 也不是因为我想要尝 园游会影片在播放  这个世界约好一起逛 光 轻如纸
# prefix-不分开:  不分开 爱深埋珊瑚海  谁都逃不掉 天平上的烦恼 你微微的笑 赤足又扭腰 朝着命运凿出一道 美艳的符号 来
#
#
# Epoch [141/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 7.4941, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你说你好累 已无法再爱上谁 风在山路吹 过往的画面 全都是我不对 细数惭愧我伤你几回 我一路
# prefix-不分开:  不分开 爱深埋珊瑚海  周杰伦  毁坏的沙雕如何重来 有裂痕的爱怎么重盖 只是一切 让我们乘着阳光　 看着
#
#
# Epoch [142/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 7.4103, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你说你好累 已无法再爱上谁 风在山路吹 过往的画面 全都是我不对 细数惭愧我伤你几回 我一路
# prefix-不分开:  不分开 说不要再说 不该 简单动作叩也不等 你看来虽不像坏蛋　 但做事做人却很蠢 你像一团沼气　 影响我的
#
#
# Epoch [143/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 7.3273, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你说你好累 已无法再爱上谁 风在山路吹 过往的画面 全都是我不对 细数惭愧 我伤你几回 后视
# prefix-不分开:  不分开 爱上 是谁来拆穿越 梦希望着我的天空 毁得很讲究 你说你走到 我也不等你 泪不休 语沉默 娘子 娘
#
#
# Epoch [144/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 7.2491, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你说你好累 已无法再爱上谁 风在山路吹 过往的画面 全都是我不对 细数惭愧我伤你几回 停止狼
# prefix-不分开:  不分开 爱深埋珊瑚海  周杰伦  毁坏的沙雕如何重来 有裂痕的爱怎么重盖 只是一切 结束太快 你说不该有太
#
#
# Epoch [145/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 7.1741, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你说你好累 已无法再爱上谁 风在山路吹 过往的画面 全都是我不对 细数惭愧我伤你几回 后视镜
# prefix-不分开:  不分开 爱深埋珊瑚海  周杰伦 一只能不到那么简单 来不及听见 你已走得很远 也许你已经放弃我 也许已经很
#
#
# Epoch [146/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 7.0985, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你会更难过 你发如雪 纷飞了眼泪 我等待苍老了谁 红尘醉 微醺的岁月 我用无悔 刻永世爱你的
# prefix-不分开:  不分开 爱可不可以不要这个奖 不想问 我在一座 窗 变了我超好  再怎么粗糙 我都要活 说你不该 不再咬
#
#
# Epoch [147/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 7.0241, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你会更难过 你比从前快乐 那祝福的话叫我如何能够说的出口 过往的欢乐是否褪色想问你怎么舍得
# prefix-不分开:  不分开 爱深埋珊瑚海  周杰伦  只有一个世界 的爱情 苔藓绿了木屋 路深处  翠落的孟宗竹 乱石堆上有雾
#
#
# Epoch [148/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 6.9525, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你会更难过 你已经远远离开 我也会慢慢走开 为什么我连分开都迁就着你 我真的没有天份 安静的
# prefix-不分开:  不分开 爱深埋珊瑚海  谁都逃不掉 天平上的烦恼 你微微的笑 赤足又扭腰 朝着命运凿出一道 美艳的符号 来
#
#
# Epoch [149/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 6.8814, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你会更难过 你已经远远离开 我也会慢慢走开 为什么我连分开都迁就着你 我真的没有天份 安静的
# prefix-不分开:  不分开 说不会该不会该不好不开 也只是曾经三国黄的春  输跟赢的分寸计算的很准  我踏上风火轮在飘移青春
#
#
# Epoch [150/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 6.8104, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你会不会懂事你累 已经待在谷底 我知道不能再留住你 也知道不能没有孤寂 感激你让我拥有缺点的
# prefix-不分开:  不分开 没有爱过的 清楚 说我爱情 只有你不会懂不见罪的温柔 暴晒在一旁的寂寞 我一定就走是你 你说我吃你
#
#
# Epoch [151/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 6.7430, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你说你好累 已经决定穿什么内容不忠 所有回忆对着我进攻 我的伤口被你拆封 誓言太沉重泪被纵容
# prefix-不分开:  不分开 没有你 我不想这个奖 不想问 我只想要留一点汗 我当我自己的裁判 不想说 选择对手跟要打的仗 全体
#
#
# Epoch [152/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 6.6755, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你会不会学会尖叫  尖叫  比从前度何必听我吠 再不走有今生无下世 你是否想我起这个毒誓 宁
# prefix-不分开:  不分开 爱可不可以不要问 我对我紧紧跟随的伤悲 细数惭愧 我伤你几回 后视镜里的世界 越来越远的道别 你转
#
#
# Epoch [153/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 6.6101, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你说你好累 已无法再爱上谁 风在山路吹 过往的画面 全都是我不对 细数惭愧我伤你几回 我一路
# prefix-不分开:  不分开不知道 就算没有结果 我也能够承受 我知道你的痛 是我给的承诺 你说给过我纵容 沉默是因为包容 如果
#
#
# Epoch [154/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 6.5456, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你会不会 让我忘了你是谁 夜越黑　梦违背 难追难回味 我的世界将被摧毁 也许事与愿违 累不累
# prefix-不分开:  不分开 爱深埋珊瑚海  周杰伦  只能不能给我一首歌的时间 把故事听到最后才说再见 你送我的眼泪 让它留在
#
#
# Epoch [155/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 6.4812, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你会不会学会自导自演心痛 我看不懂 我会更难过 你也会慢慢走开 为什么我连分开都迁就着你 我
# prefix-不分开:  不分开 说不会该不会该不好笑不要再说 别怪我 别怪我 说你怎么面对我 甩开球我满腔的怒火 我想揍你已经很久
#
#
# Epoch [156/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 6.4189, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你说你好累 已无法再爱上谁 风在山路吹 过往的画面 全都是我不对 细数惭愧我伤你几回 我一路
# prefix-不分开:  不分开 爱深埋珊瑚海  周杰伦  毁坏的沙雕如何重来 有裂痕的爱怎么重盖 只是一切 结束太快 你说你无法释
#
#
# Epoch [157/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 6.3576, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你说你好累 已无法再爱上谁 风在山路吹 过往的画面 全都是我不对 细数惭愧我伤你几回 我一路
# prefix-不分开:  不分开 没有爱过  每天我在想秋 想想想想著你 我知道 不是因为我想再淋一遍 没想到失去的勇气我还留着 好
#
#
# Epoch [158/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 6.2966, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你说你好累 已经远远离开 我也会慢慢走开 为什么我连分开都迁就着你 我真的没有天份 安静的没
# prefix-不分开:  不分开不知道 不会怎么会你竟原谅了我 我只能永远读着对白 读到我给你的伤害 我原谅不了我 就请你当作我已不
#
#
# Epoch [159/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 6.2389, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你说你好累 已无法再爱上谁 风在山路吹 过往的画面 全都是我不对 细数惭愧我伤你几回 我一路
# prefix-不分开:  不分开 爱深埋珊瑚海  谁都想很久 别想你是陪伴奏 后才发现 没有了样 我真的不知不到老头 你会陪你 最大
#
#
# Epoch [160/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 6.1828, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你说你好累 已无法再爱上谁 风在山路吹 过往的画面 全都是我不对 细数惭愧我伤你几回 我一路
# prefix-不分开:  不分开不知道 就算没有结果 我也能够承受 我知道你的痛 是我给的承诺 你说给过我纵容 沉默是因为包容 如果
#
#
# Epoch [161/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 6.1253, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你说你好累 已经决定不走错了 你好笑 你说的爱我而过 请你记得我 跑得比别 我才有个依靠 有
# prefix-不分开:  不分开 没办法 我不需要解释 所以他小丑我是大师 你的回话凌乱着 在这个时刻 我想起喷泉旁的白鸽  甜蜜散
#
#
# Epoch [162/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 6.0700, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你会不会学会尖叫  尖叫  比从前度何必听我吠 再不走有今生无下世 你是否想我起这个毒誓 宁
# prefix-不分开:  不分开不知道 就算没有结果 我也能够承受 我知道你的痛 是我给的承诺 你说给过我纵容 沉默是因为包容 如果
#
#
# Epoch [163/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 6.0166, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你会更难过 你已经远远离开 我也会慢慢走开 为什么我连分开都迁就着你 我真的没有天份 安静的
# prefix-不分开:  不分开 没办法 我不需要解释 所以他小丑我是大师 你的回话凌乱着 在这个时刻 我想起喷泉旁的白鸽  甜蜜散
#
#
# Epoch [164/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 5.9641, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你会更难过 你已经远远离开 我也会慢慢走开 为什么我连分开都迁就着你 我真的没有天份 安静的
# prefix-不分开:  不分开 爱深埋珊瑚海  周杰伦  毁坏的沙雕如何重来 有裂痕的爱怎么重盖 只是一切都想要 我感动了太爱完了
#
#
# Epoch [165/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 5.9144, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你会不会学会自导自演心痛 我看不懂 我会更难过 没有了雨 雨刷开始不停左右 就像回忆 开始对
# prefix-不分开:  不分开不知道 就算没有结果 我也能够承受 我知道你的痛 是我给的承诺 你说给过我纵容 沉默是因为包容 如果
#
#
# Epoch [166/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 5.8643, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你说你好累 已无法再爱上谁 风在山路吹 过往的画面 全都是我不对 细数惭愧我伤你几回 我一路
# prefix-不分开:  不分开 没办法 我不需要被崇拜 如兽般的悲哀 只為永恒的乐曲存在 醒过来 鐘逆时鐘而绕 恶物狰狞的倾巢 我
#
#
# Epoch [167/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 5.8133, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你说你好陪我到老 永恒往哪里找 再次拥抱 一分一秒都好 天凉了 雨下了 你走了 清楚了 我爱
# prefix-不分开:  不分开不知道 就算没有结果 我也能够承受 我知道你的痛 是我给的承诺 你说给过我纵容 沉默是因为包容 如果
#
#
# Epoch [168/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 5.7653, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你会不会手牵着一起手 就算放开但能不能别没收我的爱情 粗心的眼泪是多余 我知道你我都没有错
# prefix-不分开:  不分开 为什么还要我怎么要 这样打我妈妈 因为母斑鸠 印地安老斑鸠 腿短毛不多 几天都没有喝水也能活 脑袋
#
#
# Epoch [169/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 5.7172, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你说你好累 已无法再爱上谁 风在山路吹 过往的画面 全都是我不对 细数惭愧我伤你几回 后视镜
# prefix-不分开:  不分开 爱上的时间 你的你不知道 就是那么简单你说 不用麻烦了 不用麻烦不用麻烦了 不用麻烦了 你们一起上
#
#
# Epoch [170/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 5.6693, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你会不会倒解 你的灵魂属于我 尼罗河悄悄 漫过纸莎草 蜿蜒像一袭不带感情的纱袍 而你穿上后转
# prefix-不分开:  不分开 没有爱过  难道你离开我回家的那笑话怎么睡得了 我们开了我后悔 我没有胆挂念 你没有心见面 试问我
#
#
# Epoch [171/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 5.6218, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你会等待还是  换手 那就是一场默剧 你的黑色幽默 想通 却又再考倒我 说散 你想很久了吧?
# prefix-不分开:  不分开 没有你 不到我 我去追了怎么要 天空这个那个流星 大喊后会不会有奇跡 就算做朋友也没关系 為你改变
#
#
# Epoch [172/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 5.5779, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你会不会懂事 不真的 因为是 不上 你没有舍不得 真想就得飘　得吃你要我的感觉 你已听不见
# prefix-不分开:  不分开 没道理 那就让我 带着孤寂 继续前进 直到光明 这生命 对每个人 都不公平 也没道理 只能扑向 泥
#
#
# Epoch [173/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 5.5336, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你会更难过去 三分球 它在空中停留 所有人看着我 抛物线进球 单手过人运球 篮下妙传出手 漂
# prefix-不分开:  不分开 没办法 我们并一个香味 说散一直徘徊 我舍不得离开 生命就得飘　 你对着对着这些 太威胁 太强烈
#
#
# Epoch [174/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 5.4900, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你会不会懂事你不了 你说你也已经很久 别想躲 说你眼睛看着我 别发抖 快给我抬起头 有话去对
# prefix-不分开:  不分开 说不要走天地对我的事 可以可以放弃了 情绪偏离轨道　 快疯掉　我睡不着 我不能把爱渐渐 放下会走更
#
#
# Epoch [175/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 5.4478, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你会不会学会自导自演心痛 我看不懂 我会更难过 没有了雨 雨刷开始不停左右 就像回忆 开始对
# prefix-不分开:  不分开 为什么还要我说好有 因為我把诗摺叠 邮寄出感觉 夹一束白玫瑰 你将爱退回 我不落泪 忍住感觉 分手
#
#
# Epoch [176/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 5.4052, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你说你好累 已无法再爱上谁 风在山路吹 过往的画面 全都是我不对 细数惭愧我伤你几回 我一路
# prefix-不分开:  不分开 没办法 我不需要解释 所以他小丑我是大师 你举手 你抬头 你说我选我选我 我将牌 换颜色 变出你的
#
#
# Epoch [177/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 5.3650, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你说你好累 已无法再爱上谁 风在山路吹 过往的画面 全都是我不对 细数惭愧我伤你几回 我一路
# prefix-不分开:  不分开 没有爱过  清晰可见 上色的美  面成灰 我只是永无止境的外婆生活 活着生命就该完整地过 过过 过
#
#
# Epoch [178/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 5.3241, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你说你好累 已无法再爱上谁 风在山路吹 过往的画面 全都是我不对 细数惭愧 我伤你几回 后视
# prefix-不分开:  不分开不知道 就要离开就能不能承受我 说分离不开大 而我用功读书 用功读书 怎么会从我嘴巴说出 不想你输
#
#
# Epoch [179/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 5.2834, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你说你好累 已无法再爱上谁 风在山路吹 过往的画面 全都是我不对 细数惭愧我伤你几回 我一路
# prefix-不分开:  不分开 没有你 我不出口 你说了这样 我很有个音乐是那么简单 有人能切都太深 我安静的於是又一种 我叫做
#
#
# Epoch [180/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 5.2442, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你说你好累 已无法再爱上谁 风在山路吹 过往的画面 全都是我不对 细数惭愧我伤你几回 我一路
# prefix-不分开:  不分开 没有你 我不需要我这个光  你说你好像 没法挑剔它 口感味觉还不差 陆羽泡的茶 听说名和利都不拿
#
#
# Epoch [181/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 5.2051, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 但愿意再爱一遍 想要对你说的不敢说的爱 會会不会會有人可以明白 我会发著呆  然後忘记你
# prefix-不分开:  不分开 没办法 我不需要解释 所以他小丑我是大师 你的回话凌乱着 在这个时刻 我想起喷泉旁的白鸽  甜蜜散
#
#
# Epoch [182/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 5.1683, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你说你好累 已无法再爱上谁 风在山路吹 过往的画面 全都是我不对 细数惭愧我伤你几回 我一路
# prefix-不分开:  不分开 没办法 我不需要解释 所以他小丑我是大师 你的回话凌乱着 在这个时刻 我想起喷泉旁的白鸽  甜蜜散
#
#
# Epoch [183/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 5.1312, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你会不会懂事 不说 哎哟 微笑后 表情终于有点难过 握着你的手 问你 确定了再走 我突然释怀
# prefix-不分开:  不分开 没办法 我不需要解释 所以他小丑我是大师 你的回话凌乱着 在这个时刻 我想起喷泉旁的白鸽  甜蜜散
#
#
# Epoch [184/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 5.0946, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你说你好累 已无法再爱上谁 风在山路吹 过往的画面 全都是我不对 细数惭愧我伤你几回 后视镜
# prefix-不分开:  不分开不知道 力没有伤害 你 靠着我的肩膀 你 在我胸口睡著 像这样的生活 我爱你 你爱我 开不了口 周杰
#
#
# Epoch [185/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 5.0584, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你会不会懂事 不真的 开道的 慢慢清晰 原来思念你 是加了糖 的消息 我用铅笔 画得很仔细
# prefix-不分开:  不分开 没办法 我不需要解释 所以他小丑我是大师 你的回话凌乱着 在这个时刻 我想起喷泉旁的白鸽  甜蜜散
#
#
# Epoch [186/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 5.0233, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你说你好累 已无法再爱上谁 风在山路吹 过往的画面 全都是我不对 细数惭愧我伤你几回 我一路
# prefix-不分开:  不分开 没有爱过  难道你离开有回忆 那笑每个人 都会不会 竟原谅了这个好一只要我这种身世 有甚么资格 献
#
#
# Epoch [187/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 4.9886, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 就算是别人的回忆 没有了过去 我将往事抽离 如果我遇见你是一场悲剧 我可以让生命就这样毫无意
# prefix-不分开:  不分开 没办法 再来一次 如果你加几个音就变乡村风味 大家听久了都  咩  会狠想喝牛奶 牛仔狠忙 没有空
#
#
# Epoch [188/250]
# ...
# prefix-不分开:  不分开不知道 不会学人开心 来找不 我想你笑　 我的烦恼 你的爱 你爱完全吸收 我微笑着 让美丽 纪录第一
#
#
# Epoch [189/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 4.9198, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你说你好陪我到老 永恒往哪里找 再次拥抱 一分一秒都好 天凉了 雨下了 你走了 清楚了 我爱
# prefix-不分开:  不分开 没有爱过  难道你离开有回忆了吧  我说你也会难过 你说的爱我 还在回味你给过的温柔 我轻轻地尝一
#
#
# Epoch [190/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 4.8863, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你说你好累 已无法再爱上谁 风在山路吹 过往的画面 全都是我不对 细数惭愧我伤你几回 我一路
# prefix-不分开:  不分开不知道 就算没有结果 我也能够承受 我知道你的痛 是我给的承诺 你说给过我纵容 沉默是因为包容 如果
#
#
# Epoch [191/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 4.8530, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你会不会懂不懂事 没有你看着  这些我太快 你说好慢慢习惯 你已经不对我努力在挽回 一些些应
# prefix-不分开:  不分开 没有你 不到我 我手 你不好一口 你说的爱情 粗心的眼泪是多余 我知道你我都没有错 只是忘了怎么退
#
#
# Epoch [192/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 4.8209, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你说你好陪我到老 永恒往哪里找 再次拥抱 一分一秒都好 天凉了 雨下了 你走了 清楚了 我爱
# prefix-不分开:  不分开不知道 就算没有结果 我也能够承受 我知道你的痛 是我给的承诺 你说给过我纵容 沉默是因为包容 如果
#
#
# Epoch [193/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 4.7887, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你会不会懂不见罪的糖果 不知不觉 你已经离开我 不知不觉 我跟了这节奏 后知后觉 又过了一个
# prefix-不分开:  不分开 没有你 我不需要我这个吧 又想了谁都难过 印地安斑鸠 会学人开口 仙人掌怕羞 蜥蝪横著走 这里什么
#
#
# Epoch [194/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 4.7571, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你说你好累 已无法再爱上谁 风在山路吹 过往的画面 全都是我不对 细数惭愧我伤你几回 我一路
# prefix-不分开:  不分开 没有你 我不需要我这个光  你回家看看见 上色的美丽 没有了雨 雨刷开始不停左右 就像回忆 开始对
#
#
# Epoch [195/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 4.7264, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你会不会一直走到最后 就算没有结果 我也能够承受 我知道你的痛 是我给的承诺 你说给过我纵容
# prefix-不分开:  不分开 没有你 我不需要被崇拜 我不需要被崇拜 我跨越过时代 如兽般的姿态 琴声唤醒沈睡的血脉 不需要被崇
#
#
# Epoch [196/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 4.6958, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 就算是我们相信 说好有时光机 我谢谢你 MUSIC 妖兽扰乱人间秩序 血腥如浪潮般来袭 我小
# prefix-不分开:  不分开 没有爱过  过去 你流眼泪 分手说不出来  分手说不出来 海鸟跟鱼相爱 只是一场意外 我们的爱 给
#
#
# Epoch [197/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 4.6657, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你说你好累 已无法再爱上谁 风在山路吹 过往的画面 全都是我不对 细数惭愧 我伤你几回 后视
# prefix-不分开:  不分开 没办法 我不需要解释 所以他小丑我是大师 你的回话凌乱着 在这个时刻 我想起喷泉旁的白鸽  甜蜜散
#
#
# Epoch [198/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 4.6354, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你说你好累 已无法再爱上谁 风在山路吹 过往的画面 全都是我不对 细数惭愧 我伤你几回 后视
# prefix-不分开:  不分开 没办法 我不需要解释 所以他小丑我是大师 你的回话凌乱着 在这个时刻 我想起喷泉旁的白鸽  甜蜜散
#
#
# Epoch [199/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 4.6061, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你说你好累 已无法再爱上谁 风在山路吹 过往的画面 全都是我不对 细数惭愧我伤你几回 我一路
# prefix-不分开:  不分开 没有爱 我不能 这些弓 听得到底哪有人海中漂泊一身落寞 亲人纷纷入座 兵戎相见如果 千军万马万马
#
#
# Epoch [200/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 4.5785, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你说你好累 已无法再爱上谁 风在山路吹 过往的画面 全都是我不对 细数惭愧我伤你几回 我一路
# prefix-不分开:  不分开 没办法 我不需要解释 所以他小丑我是大师 你举手 你抬头 你说我选我选我 我将牌 换颜色 变出你的
#
#
# Epoch [201/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 4.5503, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 但愿意再爱一遍 想要对你说的不敢说的爱 會会不会會有人可以明白 我会发著呆  然後忘记你
# prefix-不分开:  不分开不知道 就算没有结尾  憔悴后悔等等这些 於是我把诗摺叠 邮寄出感觉 夹一束白玫瑰 你将爱退回 我不
#
#
# Epoch [202/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 4.5231, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你会不会手牵着一起毕业的学校 而眼泪一直都忘记要掉 嘲笑的声音在风中不断被练习 这树林间充满
# prefix-不分开:  不分开 没办法 我不需要解释 所以他小丑我是大师 你的回话凌乱着 在这个时刻 我想起喷泉旁的白鸽  甜蜜散
#
#
# Epoch [203/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 4.4956, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你会不会懂事 不说 哎哟 微笑后 表情终于有点难过 握着你的手 问你 确定了再走 我突然释怀
# prefix-不分开:  不分开 没不能 我不对 这不是我要的天堂景象 沉沦假象 你只会感到更加沮丧   难道这不是我要的天堂景象
#
#
# Epoch [204/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 4.4688, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 但愿意再爱一遍 想要对你说的不敢说的爱 會会不会會有人可以明白 我会发著呆  然後忘记你
# prefix-不分开:  不分开 没不能 我不对 这不是我要对着我害 你 在想你的好笑 再问一遍 你会等待 读到我的爱上你 可爱的脸
#
#
# Epoch [205/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 4.4421, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你会更难过去 以父我已坠入 看不见罪的国度 请原谅我的自负 没人能说没人可说 好难承受 荣耀
# prefix-不分开:  不分开不知道 力没有伤害 你 靠着我的肩膀 你 在我胸口睡著 像这样的生活 我爱你 你爱我 开不了口 周杰
#
#
# Epoch [206/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 4.4163, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你会不会手牵手 你抬头 你说你出现实的自己送人 眼睛看着阳光 景一直在绕 我的笑 让你们追了
# prefix-不分开:  不分开 没办法 我不需要解释 所以他小丑我是大师 你的回话凌乱着 在这个时刻 我想起喷泉旁的白鸽  甜蜜散
#
#
# Epoch [207/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 4.3901, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你会更难过去不重  爱你不知不觉 你已经离开我 不知不觉 我跟了这节奏 后知后觉 又过了一个
# prefix-不分开:  不分开 没不能 我不好一定 我手机会对着一张学校里学的小时候 犹记得你叫我最爱的名和利都不拿 爷爷泡的茶
#
#
# Epoch [208/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 4.3648, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你会不会个人慢慢的回忆 没有了过去 我将往事抽离 如果我遇见你是一场悲剧 我轻轻的叹息 后悔
# prefix-不分开:  不分开 没有爱 我不能 再见 你一个大的 等你 听不见的狗 接下走这 为什么这么简单你做不到 坐车厢朝着南
#
#
# Epoch [209/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 4.3395, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你会不会学
250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 4.0240, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你会不会学会开口 不说的事情 好像还没有 有些事没办法教 表错情的感觉有一点糟 赖着不走会让
# prefix-不分开:  不分开 为什么还要我用微笑来带过 我没有这种天份 包容你也接受他 不用担心的太多 我会一直好好过 你已经远
#
#
# Epoch [224/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 4.0036, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你会不会懂事 不说我 爱你说 不想 原来难道要我的证据 让晶莹的泪滴 闪烁成回忆 伤人的美丽
# prefix-不分开:  不分开 为什么还要我用微笑来带过 我没有这种天份 包容你也接受他 不用担心的太多 我会一直好好过 你已经远
#
#
# Epoch [225/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 3.9832, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 就算是我不懂 能不能原谅我 请不要把分手当作你的请求 我知道坚持要走是你受伤的借口 请你回头
# prefix-不分开:  不分开不知道 简单一句爱说不出来 经过山丘 嗨呦嗨呦 汗一直流 行李不多 但思念一定带走 朗gia刚掉路
#
#
# Epoch [226/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 3.9633, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你会更难过去的熟悉 照后镜的你比脑海清晰 你我距离就像打滑和那飘移 差狠远但看似狠接近 车灯
# prefix-不分开:  不分开不知道 力没有伤害 你 靠着我的肩膀 你 在我胸口睡著 像这样的生活 我爱你 你爱我 我想就这样牵着
#
#
# Epoch [227/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 3.9437, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你说你好累 已无法再爱上谁 风在山路吹 过往的画面 全都是我不对 细数惭愧我伤你几回 后视镜
# prefix-不分开:  不分开 没办法 我不配 天空这个路  我说 不要再这样打我妈妈 我说的话你甘会听 不要再这样打我妈妈 难道
#
#
# Epoch [228/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 3.9248, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 没有了雨 雨刷开始不停左右 就像回忆 开始对我挥了挥了手 仪表板转动 在猜我会不会懂 速度再快也追
# prefix-不分开:  不分开 知道很简单　 你说依赖是我们的阻碍 就算放开但能不能别没收我的爱　 当作我最后才明白 看不见你的笑
#
#
# Epoch [229/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 3.9053, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你会不会懂事 不说我 本事一把剪刀一堆废话 还不是想求求你回来吧 麦搁一个人咧生气 乎伊烦恼
# prefix-不分开:  不分开 没不能 我不对 我手不住那就快  加足了马力飘到底看仔细  零到一百公里谁敢与我为敌  我用第一人
#
#
# Epoch [230/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 3.8865, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你会更难过去不重  爱你不要再开 真不该 睁不开 别让我的地球变暗  街角的消防栓上的红色油
# prefix-不分开:  不分开 爱深埋珊瑚海  周杰伦  毁坏的沙雕如何重来 有裂痕的爱怎么重盖 只是一切 结束太快 你说你无法释
#
#
# Epoch [231/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 3.8674, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你说你好累 已无法再爱上谁 风在山路吹 过往的画面 全都是我不对 细数惭愧我伤你几回 我一路
# prefix-不分开:  不分开 没不能 我不难过 你比我不我的狗 用自己的药份量刚刚好 听我说中药苦抄写应该更苦 快翻开本草纲目多
#
#
# Epoch [232/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 3.8490, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你会不会懂事 不说我 觉得好一些 拯救地球好累 虽然有些疲惫 但我还是会 不要问我哭过了没
# prefix-不分开:  不分开 为什么还要我用微笑来带过 我没有这种天份 包容你也接受他 不用担心的太多 我会一直好好过 你已经远
#
#
# Epoch [233/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 3.8315, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你会不会手牵着一起毕业的学校 而眼泪一直都忘记要掉 嘲笑的声音在风中不断被练习 这树林间充满
# prefix-不分开:  不分开 为什么还要我用微笑来带过 我没有这种天份 包容你也接受他 不用担心的太多 我会一直好好过 你已经远
#
#
# Epoch [234/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 3.8143, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开都迁就着你 我真的没有天份 安静的没这么快 我会学着放弃你 是因为我太爱你 是因为我太爱你 该不该搁
# prefix-不分开:  不分开 为什么还要我用微笑来带过 我没有这种天份 包容你也接受他 不用担心的太多 我会一直好好过 你已经远
#
#
# Epoch [235/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 3.7966, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开都迁就着你 我真的没有天份 安静的没这么快 我会学着放弃你 是因为我太爱你 是因为我太爱你你要我说多
# prefix-不分开:  不分开 为什么还要我用微笑来带过 我没有这种天份 包容你也接受他 不用担心的太多 我会一直好好过 你已经远
#
#
# Epoch [236/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 3.7786, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你说你好累 已无法再爱上谁 风在山路吹 过往的画面 全都是我不对 细数惭愧我伤你几回 我一路
# prefix-不分开:  不分开 没不能 我不对 这种不要再想 我不 我不 我不能 爱情走的太快就像龙卷风 不能承受我已无处可躲 我
#
#
# Epoch [237/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 3.7616, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你说你好累 已无法再爱上谁 风在山路吹 过往的画面 全都是我不对 细数惭愧我伤你几回 我一路
# prefix-不分开:  不分开 没有你 我给我一种学习考试   就是我不好 我就这样一直接 问我忘了你 我不要再想 我不 我不 我
#
#
# Epoch [238/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 3.7445, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开都迁就着你 我真的没有天份 安静的没这么快 我会学着放弃你 是因为我太爱你是因为我太爱你 只剩下钢琴
# prefix-不分开:  不分开 没有了  爱你 我不懂 我不能 爱情走的太快就像龙卷风 不能承受我已无处可躲 我不要再想 我不要再
#
#
# Epoch [239/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 3.7278, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开都迁就着你 我真的没有天份 安静的没这么快 我会学着放弃你 是因为我太爱你 是因为我太爱你 是因为我
# prefix-不分开:  不分开 为什么还要我用微笑 再开进隧道　风声潇潇 我用第一人称　在飘移青春 输跟赢的分寸　计算的很精准 我
#
#
# Epoch [240/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 3.7109, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开都迁就着你 我真的没有天份 安静的没这么快 我会学着放弃你 是因为我太爱你 是因为我太爱你你要我说多
# prefix-不分开:  不分开 没有你 我给你一张学画面 我可以没有了 我爱你 当作我的也赖是我们的阻碍 就算放开但能不能别没收我
#
#
# Epoch [241/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 3.6944, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你说你好累 已无法再爱上谁 风在山路吹 过往的画面 全都是我不对 细数惭愧我伤你几回 我一路
# prefix-不分开:  不分开不知道何时没有办法 啊 没有做完美 你离开 距离隔不开 思念变成海 在窗外进不来 原谅说太快 爱成了
#
#
# Epoch [242/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 3.6779, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开都迁就着你 我真的没有天份 安静的没这么快 我会学着放弃你 是因为我太爱你 是因为我太爱你 要我说中
# prefix-不分开:  不分开就是说不出来  那就是我在空 我就走到这样牵着我的手慢慢习惯 天真在这条路上  放弃了抵抗 跌跌撞撞
#
#
# Epoch [243/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 3.6616, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你说你好累 已无法再爱上谁 风在山路吹 过往的画面 全都是我不对 细数惭愧我伤你几回 我一路
# prefix-不分开:  不分开 没有爱过  过去 你流眼泪 别离吹得可惜没有祝福 当爱你并不孤独 不会再让你哭 我背你走到最后 能
#
#
# Epoch [244/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 3.6461, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开不知道 你说你好累 已无法再爱上谁 风在山路吹 过往的画面 全都是我不对 细数惭愧我伤你几回 我一路
# prefix-不分开:  不分开 没有爱过  过 你离开 我不能 我战法无穷 我攻势如风 用单车入宫 碾过你懊丧的脸孔 看我 我手指
#
#
# Epoch [245/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 3.6304, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开都迁就着你 我真的没有天份 安静的没这么快 我会学着放弃你 是因为我太爱你是因为我太爱你 只剩下钢琴
# prefix-不分开:  不分开 爱深埋珊瑚海  周杰伦  毁坏的沙雕如何重来 有裂痕的爱怎么重盖 只是一切 结束太快 你说你无法释
#
#
# Epoch [246/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 3.6147, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开都迁就着你 我真的没有天份 安静的没这么快 我会学着放弃你 是因为我太爱你 该不该搁下重重的壳 寻找
# prefix-不分开:  不分开 没办法 我不是孤獨的小丑 你笑了之后 不需要記得我。 燈熄的時候 滿天的星空 最明亮的是寂寞 我只
#
#
# Epoch [247/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 3.5999, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开都迁就着你 我真的没有天份 安静的没这么快 我会学着放弃你 是因为我太爱你 是因为我太爱你你要我说多
# prefix-不分开:  不分开就是不要对这个世界约会一片 让我们乘着阳光　 海上冲浪　吸引她目光 不要怕露出胸膛　 流一点汗　你成
#
#
# Epoch [248/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 3.5853, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开都迁就着你 我真的没有天份 安静的没这么快 我会学着放弃你 是因为我太爱你 是因为我太爱你 该不该搁
# prefix-不分开:  不分开就是说不出来  分手说不出来 海鸟跟鱼相爱 只是一场意外 我们的爱 给的爱  差异一直存在  回不来
#
#
# Epoch [249/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 3.5705, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 没有了雨天 哦 越过你划的线 我定了勇气的终点 你说我不该不该 不该在这时候才说爱你 要怎么证明我
# prefix-不分开:  不分开 知道很简单　 你说依赖是我们的阻碍 就算放开但能不能别没收我的爱　 当作我最后才明白 青 花 瓷
#
#
# Epoch [250/250]
# 31/31 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 3.5557, train_score: -, test_loss: -, test_score: -
#
# prefix-分开:  分开 没有了雨 雨刷开始不停左右 就像回忆 开始对我挥了挥了手 仪表板转动 在猜我会不会懂 速度再快也追
# prefix-不分开:  不分开 没给你 爱你说才明白 看不见你的笑 怎么我想就这样 我很好笑 小时候才可以不出口 没人能说没有纯白
