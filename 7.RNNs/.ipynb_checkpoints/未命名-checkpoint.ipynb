# %%
# %config ZMQInteractiveShell.ast_node_interactivity = "all"
# %pprint
# Out:
# Pretty printing has been turned OFF

# %%
import sys
sys.path.append("../d2l_func/")
from data_prepare import zip_data_jay_song, load_data_jay_song, data_iter_random, data_iter_consecutive

# %%
corpus_char = zip_data_jay_song()
corpus_index, char_to_idx, vocab_set, vocab_size = load_data_jay_song(corpus_char)

# %%
for x, y in data_iter_random(corpus_index, 4, 6):
    print(f"x: {x}")
    print(f"y: {y}")
    print("\n")
# Out:
# x: tensor([[ 686.,  757., 1659., 1142., 1932.,   47.],
#         [ 269., 2099., 2467., 1962., 2365., 2254.],
#         [2161., 1218., 1223., 2099.,  744., 1976.],
#         [2099., 2099., 1867., 2493., 2111.,  937.]])
# y: tensor([[ 757., 1659., 1142., 1932.,   47., 1142.],
#         [2099., 2467., 1962., 2365., 2254.,  502.],
#         [1218., 1223., 2099.,  744., 1976., 2099.],
#         [2099., 1867., 2493., 2111.,  937.,  118.]])
#
#
# x: tensor([[ 143., 1827., 2092., 2099., 1973.,  591.],
#         [2213.,  600., 2099.,   84.,  449.,  986.],
#         [1644., 2099., 1403., 1644., 2099., 1403.],
#         [ 243., 2099.,  780., 1704., 1403., 1537.]])
# y: tensor([[1827., 2092., 2099., 1973.,  591.,  986.],
#         [ 600., 2099.,   84.,  449.,  986., 1550.],
#         [2099., 1403., 1644., 2099., 1403., 1644.],
#         [2099.,  780., 1704., 1403., 1537.,  467.]])
#
#
# x: tensor([[2099.,  487.,  963.,   84., 1212., 2198.],
#         [2111., 1566., 1347.,  933., 2220.,  230.],
# ...

# %%
for x, y in data_iter_consecutive(corpus_index, 4, 6):
    print(f"x: {x}")
    print(f"y: {y}")
    print("\n")
# Out:
# x: tensor([[ 376., 1196., 2155., 1502., 1937., 2099.],
#         [1434.,  994., 1727.,   97.,  986., 2380.],
#         [ 759., 2099., 1718., 2208.,  640., 2200.],
#         [ 651., 1113., 2099., 1008.,  422., 1605.]])
# y: tensor([[ 377., 1197., 2156., 1503., 1938., 2100.],
#         [1435.,  995., 1728.,   98.,  987., 2381.],
#         [ 760., 2100., 1719., 2209.,  641., 2201.],
#         [ 652., 1114., 2100., 1009.,  423., 1606.]])
#
#
# x: tensor([[ 279.,  376., 2241., 1671., 1293., 2220.],
#         [1967., 2353., 2099.,  468., 1869.,  797.],
#         [ 986.,  257., 2500.,  321.,   64.,  986.],
#         [ 977., 1456., 1293., 1937., 1305.,   32.]])
# y: tensor([[ 280.,  377., 2242., 1672., 1294., 2221.],
#         [1968., 2354., 2100.,  469., 1870.,  798.],
#         [ 987.,  258., 2501.,  322.,   65.,  987.],
#         [ 978., 1457., 1294., 1938., 1306.,   33.]])
#
#
# x: tensor([[1658., 1495., 1973., 2099.,  279.,  376.],
#         [1964., 2099.,   78.,  236.,  854.,  986.],
# ...
