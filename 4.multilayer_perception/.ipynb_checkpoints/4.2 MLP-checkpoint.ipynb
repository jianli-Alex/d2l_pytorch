# %%
# %config ZMQInteractiveShell.ast_node_interactivity = "all"
# %pprint
# Out:
# Pretty printing has been turned OFF

# %% [markdown]
# ## relu实现

# %% [markdown]
# $Relu = max(0, x)$
# - 过往的神经网络都常用sigmoid和tanh(x)
# - 但是sigmoid有诸如存在饱和区域，计算量大，非零中心化缺点
# - relu不存在饱和区域，导数简单，计算快（随着网络层数的增加，sigmoid计算缓慢），单侧抑制
#     - 但是左侧区域会出现“死亡”
# - 其导数为I(x>0)

# %%
import sys
sys.path.append("../d2l_func/")
import torch
import matplotlib.pyplot as plt
from draw import set_fig_display

# %matplotlib inline
plt.rcParams["axes.spines.top"] = False
plt.rcParams["axes.spines.right"] = False
plt.rcParams["figure.figsize"] = [14, 7]
plt.rcParams["font.size"] = 14
plt.rcParams["axes.facecolor"] = "WhiteSmoke"

# %%
x = torch.arange(-8, 8, 0.1, requires_grad=True)
y = x.relu()
# 有梯度的时候画不了图
plt.plot(x.detach().numpy(), y.detach().numpy())

# %%
# 梯度回传(只能是一个数字)
y.sum().backward()
plt.plot(x.detach().numpy(), x.grad.detach().numpy())

# %% [markdown]
# ## sigmoid实现

# %% [markdown]
# $sigmoid(x) = \frac{1}{1+exp(-x)}$

# %%
y = x.sigmoid()
plt.plot(x.detach().numpy(), y.detach().numpy())

# %% [markdown]
# 导数为$(1- sigmoid(x))sigmoid(x)$

# %%
# 之前使用过，要梯度清零
x.grad.data.zero_()
y.sum().backward()
plt.plot(x.detach().numpy(), x.grad.detach().numpy())

# %% [markdown]
# sigmoid梯度的取值范围为[0, 0.25]

# %% [markdown]
# ## tanh

# %% [markdown]
# $tanh(x) = \frac{exp(x) - exp(-x)}{exp(x) + exp(-x)}$

# %%
# y = (torch.exp(x) - torch.exp(-x)) / (torch.exp(x) + torch.exp(-x))
y = x.tanh()
plt.plot(x.detach().numpy(), y.detach().numpy())

# %% [markdown]
# 导数为$1- tanh^2(x)$

# %%
# 之前使用过，要梯度清零
x.grad.data.zero_()
y.sum().backward()
plt.plot(x.detach().numpy(), x.grad.detach().numpy())

# %% [markdown]
# $tanh梯度的取值范围为[0, 1]$

# %% [markdown]
# ## MLP从零实现

# %%
import sys
import torch
import torch.utils.data as Data
sys.path.append("../d2l_func/")
from model_train import train_pytorch
from data_prepare import download_data_fashion_mnist, load_data_fashion_mnist

# %%
class MLP(object):
    def __init__(self, input_num, hidden_num, output_num):
        self.w1 = torch.normal(0, 0.01, size=(input_num, hidden_num), requires_grad=True)
        self.b1 = torch.zeros(hidden_num, requires_grad=True)
        self.w2 = torch.normal(0, 0.01, size=(hidden_num, output_num), requires_grad=True)
        self.b2 = torch.zeros(output_num, requires_grad=True)
        self.input_num = input_num
        self.hidden_num = hidden_num
        self.output_num = output_num
        
    @staticmethod
    def linreg(X, w, b):
        return torch.mm(X, w) + b
    
    @staticmethod
    def relu(y_pred):
        # pytorch中没有maximum
        return torch.max(y_pred, torch.tensor([0.]))
    
    @staticmethod
    def softmax(y_pred):
        return torch.exp(y_pred)/(torch.exp(y_pred).sum(axis=1, keepdims=True))
    
    def entropy_loss(self, y_pred, y):
        y_pred = torch.gather(y_pred, 1, y.unsqueeze(1))
        return -(y_pred.clamp(1e-12).log()).sum() / len(y)
    
    def predict_prob(self, X):
        # reshape X
        X = X.view(-1, self.input_num)
        a1 = self.relu(self.linreg(X, self.w1, self.b1))
        y_pred = self.softmax(self.linreg(a1, self.w2, self.b2))
        return y_pred
        
    def predict(self, X):
        y_pred = self.predict_prob(X)
        y_pred = torch.argmax(y_pred, dim=1)
        return y_pred
    
    def score(self, X, y):
        y_pred = self.predict(X)
        acc = (y_pred == y).sum().item() / len(y)
        return acc

# %%
# define model
model = MLP(input_num=28*28, hidden_num=300, output_num=10)
# load data
mnist_train, mnist_test = download_data_fashion_mnist()

params = {
    "model": model.predict_prob,
    "loss": model.entropy_loss,
    "epoch_num": 50,
    "data_num": len(mnist_train),
    "batch_size": 512,
    "lr": 0.1,
    "weight_decay": 0,
    "params": [model.w1, model.b1, model.w2, model.b2],
    "test_iter": Data.DataLoader(mnist_test, batch_size=len(mnist_test)),
    "evaluate": model.score,
}


train_iter, test_iter = load_data_fashion_mnist(batch_size=params["batch_size"], num_workers=8)
params["train_iter"] = train_iter
train_pytorch(**params)
# Out:
# Epoch [1/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.8569, train_score: 0.708, test_loss: 0.9016, test_score: 0.650
#
# Epoch [2/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.6721, train_score: 0.771, test_loss: 0.7034, test_score: 0.726
#
# Epoch [3/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.6325, train_score: 0.802, test_loss: 0.7026, test_score: 0.764
#
# Epoch [4/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.4141, train_score: 0.844, test_loss: 0.5868, test_score: 0.789
#
# Epoch [5/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.4041, train_score: 0.875, test_loss: 0.5863, test_score: 0.791
#
# Epoch [6/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.4965, train_score: 0.781, test_loss: 0.5232, test_score: 0.814
#
# Epoch [7/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.4862, train_score: 0.812, test_loss: 0.6227, test_score: 0.788
#
# Epoch [8/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.4813, train_score: 0.802, test_loss: 0.5196, test_score: 0.810
#
# Epoch [9/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.4567, train_score: 0.885, test_loss: 0.6084, test_score: 0.763
#
# Epoch [10/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.5958, train_score: 0.781, test_loss: 0.5218, test_score: 0.812
#
# Epoch [11/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.3824, train_score: 0.875, test_loss: 0.4636, test_score: 0.837
#
# Epoch [12/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.5111, train_score: 0.865, test_loss: 0.4864, test_score: 0.822
#
# Epoch [13/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.4398, train_score: 0.854, test_loss: 0.4739, test_score: 0.832
#
# Epoch [14/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.5034, train_score: 0.844, test_loss: 0.4649, test_score: 0.834
#
# Epoch [15/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.2964, train_score: 0.917, test_loss: 0.4785, test_score: 0.833
#
# Epoch [16/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.3993, train_score: 0.865, test_loss: 0.4573, test_score: 0.832
#
# Epoch [17/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.3627, train_score: 0.875, test_loss: 0.4302, test_score: 0.847
#
# Epoch [18/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.3612, train_score: 0.844, test_loss: 0.4373, test_score: 0.843
#
# Epoch [19/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.4797, train_score: 0.865, test_loss: 0.4405, test_score: 0.839
#
# Epoch [20/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.4718, train_score: 0.844, test_loss: 0.5347, test_score: 0.793
#
# Epoch [21/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.2791, train_score: 0.917, test_loss: 0.4150, test_score: 0.852
#
# Epoch [22/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.1980, train_score: 0.938, test_loss: 0.4067, test_score: 0.855
#
# Epoch [23/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.3206, train_score: 0.906, test_loss: 0.4086, test_score: 0.855
#
# Epoch [24/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.3090, train_score: 0.896, test_loss: 0.4427, test_score: 0.842
#
# Epoch [25/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.3748, train_score: 0.865, test_loss: 0.4099, test_score: 0.853
#
# Epoch [26/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.3483, train_score: 0.875, test_loss: 0.4145, test_score: 0.851
#
# Epoch [27/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.5444, train_score: 0.792, test_loss: 0.4771, test_score: 0.819
#
# Epoch [28/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.3309, train_score: 0.917, test_loss: 0.4531, test_score: 0.839
#
# Epoch [29/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.2858, train_score: 0.875, test_loss: 0.4448, test_score: 0.843
#
# Epoch [30/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.3166, train_score: 0.885, test_loss: 0.3935, test_score: 0.861
#
# Epoch [31/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.4424, train_score: 0.854, test_loss: 0.4152, test_score: 0.853
#
# Epoch [32/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.2922, train_score: 0.917, test_loss: 0.4159, test_score: 0.847
#
# Epoch [33/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.3440, train_score: 0.875, test_loss: 0.3869, test_score: 0.861
#
# Epoch [34/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.2936, train_score: 0.885, test_loss: 0.3934, test_score: 0.857
#
# Epoch [35/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.2784, train_score: 0.854, test_loss: 0.3934, test_score: 0.857
#
# Epoch [36/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.4538, train_score: 0.844, test_loss: 0.4272, test_score: 0.841
#
# Epoch [37/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.2785, train_score: 0.906, test_loss: 0.3990, test_score: 0.855
#
# Epoch [38/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.3611, train_score: 0.854, test_loss: 0.3830, test_score: 0.862
#
# Epoch [39/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.3270, train_score: 0.885, test_loss: 0.4065, test_score: 0.854
#
# Epoch [40/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.2883, train_score: 0.917, test_loss: 0.3800, test_score: 0.865
#
# Epoch [41/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.2930, train_score: 0.896, test_loss: 0.3701, test_score: 0.867
#
# Epoch [42/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.2502, train_score: 0.917, test_loss: 0.4161, test_score: 0.846
#
# Epoch [43/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.3293, train_score: 0.865, test_loss: 0.4136, test_score: 0.848
#
# Epoch [44/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.4384, train_score: 0.875, test_loss: 0.3825, test_score: 0.863
#
# Epoch [45/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.2896, train_score: 0.885, test_loss: 0.4360, test_score: 0.835
#
# Epoch [46/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.2569, train_score: 0.906, test_loss: 0.3801, test_score: 0.867
#
# Epoch [47/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.3209, train_score: 0.865, test_loss: 0.3842, test_score: 0.864
#
# Epoch [48/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.1722, train_score: 0.917, test_loss: 0.3732, test_score: 0.865
#
# Epoch [49/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.2331, train_score: 0.917, test_loss: 0.4179, test_score: 0.845
#
# Epoch [50/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.2888, train_score: 0.896, test_loss: 0.3738, test_score: 0.867

# %% [markdown]
# ## MLP简洁实现

# %%
import torch
import torch.nn as nn
import torch.nn.init as init

# %%
class FlattenLayer(nn.Module):
    def __init__(self):
        super(FlattenLayer, self).__init__()
        
    def forward(self, X):
        X = X.view(X.shape[0], -1)
        return X
        
class MLPModel(nn.Module):
    def __init__(self):
        super(MLPModel, self).__init__()
        self.layer = nn.Sequential(
            FlattenLayer(),
            nn.Linear(784, 300),
            nn.ReLU(),
            nn.Linear(300, 10),
        )
        
    def forward(self, X):
        y = self.layer(X)
        return y
    
    def score(self, X, y):
        y_pred = self.forward(X)
        acc = (y_pred.argmax(dim=1) == y).sum().item() / len(y)
        return acc

# %%
# define model
model = MLPModel()

# init weight and bias
for net in model.layer:
    if isinstance(net, nn.Linear):
        _ = init.normal_(net.weight, 0, 0.01)
        _ = init.constant_(net.bias, 0)
        
# loss
loss = nn.CrossEntropyLoss()
# load data
mnist_train, mnist_test = download_data_fashion_mnist()

params = {
    "model": model,
    "loss": loss,
    "epoch_num": 50,
    "data_num": len(mnist_train),
    "batch_size": 512,
    "lr": 0.1,
    "weight_decay": 0,
    "test_iter": Data.DataLoader(mnist_test, batch_size=len(mnist_test)),
    "evaluate": model.score,
}

# optimizer
optimizer = torch.optim.SGD(model.parameters(), lr=params["lr"], 
                            weight_decay=params["weight_decay"], momentum=0.9)
train_iter, test_iter = load_data_fashion_mnist(batch_size=params["batch_size"], num_workers=8)
params["train_iter"] = train_iter
params["optimizer"] = optimizer

# training
train_pytorch(**params)
# Out:
# Epoch [1/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.5733, train_score: 0.750, test_loss: 0.5113, test_score: 0.816
#
# Epoch [2/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.2791, train_score: 0.885, test_loss: 0.4218, test_score: 0.849
#
# Epoch [3/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.4663, train_score: 0.823, test_loss: 0.4067, test_score: 0.855
#
# Epoch [4/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.3964, train_score: 0.823, test_loss: 0.3843, test_score: 0.863
#
# Epoch [5/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.2976, train_score: 0.865, test_loss: 0.3674, test_score: 0.867
#
# Epoch [6/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.4027, train_score: 0.885, test_loss: 0.3831, test_score: 0.860
#
# Epoch [7/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.3137, train_score: 0.854, test_loss: 0.3612, test_score: 0.867
#
# Epoch [8/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.2828, train_score: 0.896, test_loss: 0.3594, test_score: 0.871
#
# Epoch [9/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.1555, train_score: 0.948, test_loss: 0.3423, test_score: 0.879
#
# Epoch [10/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.1799, train_score: 0.927, test_loss: 0.3413, test_score: 0.877
#
# Epoch [11/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.2727, train_score: 0.906, test_loss: 0.3367, test_score: 0.880
#
# Epoch [12/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.2647, train_score: 0.906, test_loss: 0.3365, test_score: 0.880
#
# Epoch [13/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.2342, train_score: 0.896, test_loss: 0.3360, test_score: 0.879
#
# Epoch [14/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.1718, train_score: 0.938, test_loss: 0.3285, test_score: 0.883
#
# Epoch [15/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.3346, train_score: 0.896, test_loss: 0.3473, test_score: 0.876
#
# Epoch [16/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.2351, train_score: 0.917, test_loss: 0.3289, test_score: 0.882
#
# Epoch [17/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.2345, train_score: 0.875, test_loss: 0.3585, test_score: 0.871
#
# Epoch [18/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.3666, train_score: 0.865, test_loss: 0.3340, test_score: 0.882
#
# Epoch [19/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.3215, train_score: 0.875, test_loss: 0.3278, test_score: 0.880
#
# Epoch [20/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.2438, train_score: 0.917, test_loss: 0.3234, test_score: 0.886
#
# Epoch [21/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.2088, train_score: 0.927, test_loss: 0.3346, test_score: 0.880
#
# Epoch [22/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.3075, train_score: 0.896, test_loss: 0.3302, test_score: 0.884
#
# Epoch [23/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.3020, train_score: 0.885, test_loss: 0.3286, test_score: 0.884
#
# Epoch [24/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.1410, train_score: 0.948, test_loss: 0.3248, test_score: 0.882
#
# Epoch [25/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.1076, train_score: 0.948, test_loss: 0.3438, test_score: 0.882
#
# Epoch [26/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.1640, train_score: 0.927, test_loss: 0.3323, test_score: 0.883
#
# Epoch [27/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.1547, train_score: 0.958, test_loss: 0.3500, test_score: 0.884
#
# Epoch [28/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.1417, train_score: 0.938, test_loss: 0.3275, test_score: 0.885
#
# Epoch [29/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.1975, train_score: 0.948, test_loss: 0.3514, test_score: 0.880
#
# Epoch [30/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.1817, train_score: 0.938, test_loss: 0.3262, test_score: 0.889
#
# Epoch [31/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.2107, train_score: 0.938, test_loss: 0.3306, test_score: 0.891
#
# Epoch [32/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.2179, train_score: 0.927, test_loss: 0.3540, test_score: 0.880
#
# Epoch [33/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.1883, train_score: 0.938, test_loss: 0.3519, test_score: 0.884
#
# Epoch [34/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.1184, train_score: 0.938, test_loss: 0.3289, test_score: 0.888
#
# Epoch [35/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.1063, train_score: 0.969, test_loss: 0.3247, test_score: 0.890
#
# Epoch [36/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.1287, train_score: 0.938, test_loss: 0.3397, test_score: 0.888
#
# Epoch [37/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.1499, train_score: 0.958, test_loss: 0.3402, test_score: 0.888
#
# Epoch [38/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.2467, train_score: 0.896, test_loss: 0.3851, test_score: 0.874
#
# Epoch [39/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.2078, train_score: 0.917, test_loss: 0.3914, test_score: 0.871
#
# Epoch [40/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.1876, train_score: 0.917, test_loss: 0.3321, test_score: 0.888
#
# Epoch [41/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.1211, train_score: 0.948, test_loss: 0.3392, test_score: 0.888
#
# Epoch [42/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.2003, train_score: 0.917, test_loss: 0.3451, test_score: 0.887
#
# Epoch [43/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.1113, train_score: 0.969, test_loss: 0.3634, test_score: 0.880
#
# Epoch [44/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.1763, train_score: 0.948, test_loss: 0.3660, test_score: 0.881
#
# Epoch [45/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.1541, train_score: 0.938, test_loss: 0.3380, test_score: 0.892
#
# Epoch [46/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.0861, train_score: 0.990, test_loss: 0.3435, test_score: 0.889
#
# Epoch [47/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.2237, train_score: 0.896, test_loss: 0.3943, test_score: 0.875
#
# Epoch [48/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.2154, train_score: 0.917, test_loss: 0.3518, test_score: 0.889
#
# Epoch [49/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.1115, train_score: 0.969, test_loss: 0.3608, test_score: 0.889
#
# Epoch [50/50]
# 60000/60000 [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] - train_loss: 0.0716, train_score: 0.979, test_loss: 0.3612, test_score: 0.883

# %%
# testing
from draw import get_fashion_mnist_label, show_fashion_mnist

x, y = iter(test_iter).next()
true_label = get_fashion_mnist_label(y)
pred_label = get_fashion_mnist_label(model(x).argmax(dim=1))
label = [true + "\n" + pred for true, pred in zip(true_label, pred_label)]
show_fashion_mnist(x[:10], label[:10])
